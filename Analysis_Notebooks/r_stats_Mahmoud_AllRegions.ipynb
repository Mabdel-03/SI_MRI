# %% [markdown]
# # Imports + Import Data & Set Working Directory

# %%
#!/usr/bin/env Rscript

# Load libraries
require(ggplot2)
require(reshape2)

# Step 1: Read the CSV file
bids <- "/om2/user/mabdel03/files/Ravi_ISO_MRI/Final_Data/"
#read_csv <- file.path(bids, "code", "slm_data3.csv")
read_csv <- file.path("/om2/user/mabdel03/files/Ravi_ISO_MRI/Final_Data/code/slm_data3_with_qc.csv")
data <- read.csv(read_csv)
colnames <- names(data)

# Extract subsets with QC
fmri_data <- subset(data, fmri_qc == 1)
dwi_data <- subset(data, dwi_qc == 1)
anat_data <- subset(data, anat_qc == 1)

# Set working directory
setwd('/om2/user/mabdel03/files/Ravi_ISO_MRI/Mahmoud_Rerun_Model_Outputs')
# Out:
# Loading required package: ggplot2
#
# Loading required package: reshape2

# %% [markdown]
# # Functions

# %%
#OLS Model w/ Interaction Terms, Filtering Output By Significance Threshold
run_ols_model <- function(dataframe, main_predictor, main_dependent, covariates_numeric = NULL, covariates_factor = NULL, interaction_terms = NULL, significance_level = 0.05, delta_rsq_threshold = 0.0001) {
  # Selecting relevant columns from the dataframe
  selected_vars <- c(main_predictor, main_dependent, covariates_numeric, covariates_factor)
  if (!is.null(interaction_terms)) {
    interaction_vars <- unlist(strsplit(interaction_terms, ":"))
    selected_vars <- unique(c(selected_vars, interaction_vars))
  }
  data_subset <- dataframe[, selected_vars, drop = FALSE]
  
  # Remove rows with missing values
  data_subset <- na.omit(data_subset)
  
  # Z-scoring main predictor and dependent variable along with numeric covariates if they are not empty
  numeric_cols <- c(main_predictor, main_dependent, covariates_numeric)
  if (!is.null(numeric_cols)) {
    data_subset[numeric_cols] <- scale(data_subset[numeric_cols])
  }
  
  # Converting factor variables to factor type
  if (!is.null(covariates_factor)) {
    for (factor_var in covariates_factor) {
      data_subset[[factor_var]] <- factor(data_subset[[factor_var]])
    }
  }
  

  # Constructing the full model formula
  formula_terms <- c(main_predictor, covariates_numeric, covariates_factor)
  if (!is.null(interaction_terms)) {
    formula_terms <- c(formula_terms, interaction_terms)
  }
  formula_string_full <- paste(main_dependent, "~", paste(formula_terms, collapse = " + "))
  
  # Constructing the reduced model formula (excluding the main predictor)
  reduced_terms <- setdiff(formula_terms, c(main_predictor, interaction_terms))
  formula_string_reduced <- paste(main_dependent, "~", paste(reduced_terms, collapse = " + "))
  
  # Running the full OLS model
  ols_model_full <- lm(formula_string_full, data = data_subset)
  
  # Running the reduced OLS model
  ols_model_reduced <- lm(formula_string_reduced, data = data_subset)
  
  # Calculating adjusted R-squared for the full model
  adj_rsq_full <- summary(ols_model_full)$adj.r.squared
  
  # Calculating adjusted R-squared for the reduced model
  adj_rsq_reduced <- summary(ols_model_reduced)$adj.r.squared
  
  # Calculating change in adjusted R-squared
  delta_adj_rsq <- adj_rsq_full - adj_rsq_reduced
  
  # Extracting coefficients and p-values from the full model summary
  model_summary <- summary(ols_model_full)
  coefficients <- model_summary$coefficients
  p_value_main <- coefficients[main_predictor, "Pr(>|t|)"]
  
  # Extract p-value for interaction term if provided
  if (!is.null(interaction_terms)) {
    # Check if interaction term exists in coefficients
    interaction_exists <- interaction_terms %in% rownames(coefficients)
    if (any(interaction_exists)) {
      p_value_interaction <- coefficients[interaction_terms[interaction_exists], "Pr(>|t|)", drop = FALSE]
    } else {
      p_value_interaction <- NULL
    }
  } else {
    p_value_interaction <- NULL
  }
  
  # Only print if the main predictor is statistically significant
  if (p_value_main < significance_level) {
    cat("Formula (Full Model):", formula_string_full, "\n\n")
    cat("Significant Relationship between", main_dependent, "and", main_predictor, "with p-value:", p_value_main, "\n\n")
    print(coefficients[main_predictor, , drop = FALSE])
    
    # Also print the interaction term if it is provided and significant
    if (!is.null(p_value_interaction) && any(p_value_interaction < significance_level)) {
      cat("\nSignificant Interaction Terms:\n")
      print(coefficients[interaction_terms[interaction_exists], , drop = FALSE])
    }
    
    # Print the change in adjusted R-squared
    if (delta_adj_rsq > delta_rsq_threshold) {
      cat("\nRAW Adjusted R-squared:", adj_rsq_full, "\n\n")
      cat("\nChange in Adjusted R-squared (Full vs Reduced Model):", delta_adj_rsq, "\n\n")
    }
  }
    
  
  # Returning the OLS model object, p-values, and delta R-squared
  return(list(model = ols_model_full, p_value_main = p_value_main, p_value_interaction = p_value_interaction, delta_adj_rsq = delta_adj_rsq))
}

# %%
#OLS Model w/ Interaction Terms, Filtering Output By Significance Threshold
run_ols_model <- function(dataframe, main_predictor, main_dependent, covariates_numeric = NULL, covariates_factor = NULL, interaction_terms = NULL, significance_level = 0.05, delta_rsq_threshold = 0.0001) {
  # Selecting relevant columns from the dataframe
  selected_vars <- c(main_predictor, main_dependent, covariates_numeric, covariates_factor)
  if (!is.null(interaction_terms)) {
    interaction_vars <- unlist(strsplit(interaction_terms, ":"))
    selected_vars <- unique(c(selected_vars, interaction_vars))
  }
  data_subset <- dataframe[, selected_vars, drop = FALSE]
  
  # Remove rows with missing values
  data_subset <- na.omit(data_subset)
  
  # Z-scoring main predictor and dependent variable along with numeric covariates if they are not empty
  numeric_cols <- c(main_predictor, main_dependent, covariates_numeric)
  if (!is.null(numeric_cols)) {
    data_subset[numeric_cols] <- scale(data_subset[numeric_cols])
  }
  
  # Converting factor variables to factor type
  if (!is.null(covariates_factor)) {
    for (factor_var in covariates_factor) {
      data_subset[[factor_var]] <- factor(data_subset[[factor_var]])
    }
  }
  

  # Constructing the full model formula
  formula_terms <- c(main_predictor, covariates_numeric, covariates_factor)
  if (!is.null(interaction_terms)) {
    formula_terms <- c(formula_terms, interaction_terms)
  }
  formula_string_full <- paste(main_dependent, "~", paste(formula_terms, collapse = " + "))
  
  # Constructing the reduced model formula (excluding the main predictor)
  reduced_terms <- setdiff(formula_terms, c(main_predictor, interaction_terms))
  formula_string_reduced <- paste(main_dependent, "~", paste(reduced_terms, collapse = " + "))
  
  # Running the full OLS model
  ols_model_full <- lm(formula_string_full, data = data_subset)
  
  # Running the reduced OLS model
  ols_model_reduced <- lm(formula_string_reduced, data = data_subset)
  
  # Calculating adjusted R-squared for the full model
  adj_rsq_full <- summary(ols_model_full)$adj.r.squared
  
  # Calculating adjusted R-squared for the reduced model
  adj_rsq_reduced <- summary(ols_model_reduced)$adj.r.squared
  
  # Calculating change in adjusted R-squared
  delta_adj_rsq <- adj_rsq_full - adj_rsq_reduced
  
  # Extracting coefficients and p-values from the full model summary
  model_summary <- summary(ols_model_full)
  coefficients <- model_summary$coefficients
  p_value_main <- coefficients[main_predictor, "Pr(>|t|)"]
  
  # Extract p-value for interaction term if provided
  if (!is.null(interaction_terms)) {
    # Check if interaction term exists in coefficients
    interaction_exists <- interaction_terms %in% rownames(coefficients)
    if (any(interaction_exists)) {
      p_value_interaction <- coefficients[interaction_terms[interaction_exists], "Pr(>|t|)", drop = FALSE]
    } else {
      p_value_interaction <- NULL
    }
  } else {
    p_value_interaction <- NULL
  }
  
  # Only print if the main predictor is statistically significant
  if (p_value_main < significance_level) {
    cat("Formula (Full Model):", formula_string_full, "\n\n")
    cat("Significant Relationship between", main_dependent, "and", main_predictor, "with p-value:", p_value_main, "\n\n")
    print(coefficients[main_predictor, , drop = FALSE])
    
    # Also print the interaction term if it is provided and significant
    if (!is.null(p_value_interaction) && any(p_value_interaction < significance_level)) {
      cat("\nSignificant Interaction Terms:\n")
      print(coefficients[interaction_terms[interaction_exists], , drop = FALSE])
    }
    
    # Print the change in adjusted R-squared
    if (delta_adj_rsq > delta_rsq_threshold) {
      cat("\nRAW Adjusted R-squared:", adj_rsq_full, "\n\n")
      cat("\nChange in Adjusted R-squared (Full vs Reduced Model):", delta_adj_rsq, "\n\n")
    }
  }
    
  
  # Returning the OLS model object, p-values, and delta R-squared
  return(list(model = ols_model_full, p_value_main = p_value_main, p_value_interaction = p_value_interaction, delta_adj_rsq = delta_adj_rsq))
}

# %%
run_ols_model_FDR <- function(dataframe, main_predictor, main_dependent, covariates_numeric = NULL, covariates_factor = NULL, interaction_terms = NULL, significance_level = 0.05, delta_rsq_threshold = 0.0001, external_p_values = NULL) {
  # Selecting relevant columns from the dataframe
  selected_vars <- c(main_predictor, main_dependent, covariates_numeric, covariates_factor)
  if (!is.null(interaction_terms)) {
    interaction_vars <- unlist(strsplit(interaction_terms, ":"))
    selected_vars <- unique(c(selected_vars, interaction_vars))
  }
  data_subset <- dataframe[, selected_vars, drop = FALSE]
  
  # Remove rows with missing values
  data_subset <- na.omit(data_subset)
  
  # Z-scoring main predictor and dependent variable along with numeric covariates if they are not empty
  numeric_cols <- c(main_predictor, main_dependent, covariates_numeric)
  if (!is.null(numeric_cols)) {
    data_subset[numeric_cols] <- scale(data_subset[numeric_cols])
  }
  
  # Converting factor variables to factor type
  if (!is.null(covariates_factor)) {
    for (factor_var in covariates_factor) {
      data_subset[[factor_var]] <- factor(data_subset[[factor_var]])
    }
  }

  # Constructing the full model formula
  formula_terms <- c(main_predictor, covariates_numeric, covariates_factor)
  if (!is.null(interaction_terms)) {
    formula_terms <- c(formula_terms, interaction_terms)
  }
  formula_string_full <- paste(main_dependent, "~", paste(formula_terms, collapse = " + "))
  
  # Constructing the reduced model formula (excluding the main predictor)
  reduced_terms <- setdiff(formula_terms, c(main_predictor, interaction_terms))
  formula_string_reduced <- paste(main_dependent, "~", paste(reduced_terms, collapse = " + "))
  
  # Running the full OLS model
  ols_model_full <- lm(formula_string_full, data = data_subset)
  
  # Running the reduced OLS model
  ols_model_reduced <- lm(formula_string_reduced, data = data_subset)
  
  # Calculating adjusted R-squared for the full model
  adj_rsq_full <- summary(ols_model_full)$adj.r.squared
  
  # Calculating adjusted R-squared for the reduced model
  adj_rsq_reduced <- summary(ols_model_reduced)$adj.r.squared
  
  # Calculating change in adjusted R-squared
  delta_adj_rsq <- adj_rsq_full - adj_rsq_reduced
  
  # Extracting coefficients and p-values from the full model summary
  model_summary <- summary(ols_model_full)
  coefficients <- model_summary$coefficients
  p_values <- coefficients[, "Pr(>|t|)"]
  
  # Combine external p-values with the model's p-values if provided
  if (!is.null(external_p_values)) {
    combined_p_values <- c(p_values, external_p_values)
  } else {
    combined_p_values <- p_values
  }
  
  # FDR correction for combined p-values
  p_values_fdr <- p.adjust(combined_p_values, method = "fdr")
  
  # Extract the FDR-corrected p-values for the main predictor and interaction terms
  p_value_main <- p_values_fdr[main_predictor]
  
  # Extract FDR-corrected p-value for interaction term if provided
  if (!is.null(interaction_terms)) {
    # Check if interaction term exists in coefficients
    interaction_exists <- interaction_terms %in% names(p_values_fdr)
    if (any(interaction_exists)) {
      p_value_interaction <- p_values_fdr[interaction_terms[interaction_exists], drop = FALSE]
    } else {
      p_value_interaction <- NULL
    }
  } else {
    p_value_interaction <- NULL
  }
  
  # Only print if the main predictor is statistically significant
  if (p_value_main < significance_level) {
    cat("Formula (Full Model):", formula_string_full, "\n\n")
    cat("Significant Relationship between", main_dependent, "and", main_predictor, "with FDR corrected p-value:", p_value_main, "\n\n")
    print(coefficients[main_predictor, , drop = FALSE])
    
    # Also print the interaction term if it is provided and significant
    if (!is.null(p_value_interaction) && any(p_value_interaction < significance_level)) {
      cat("\nSignificant Interaction Terms (FDR corrected):\n")
      print(coefficients[interaction_terms[interaction_exists], , drop = FALSE])
    }
    
    # Print the change in adjusted R-squared
    if (delta_adj_rsq >= delta_rsq_threshold) {
    cat("\nRAW Adjusted R-squared:", adj_rsq_full, "\n\n")
    cat("\nChange in Adjusted R-squared (Full vs Reduced Model):", delta_adj_rsq, "\n\n")
    }
  }
  
  # Returning the OLS model object, FDR corrected p-values, and delta R-squared
  return(list(model = ols_model_full, p_value_main_fdr = p_value_main, p_value_interaction_fdr = p_value_interaction, delta_adj_rsq = delta_adj_rsq))
}

# %% [markdown]
# ## DWI Data

# %%
# Run a model
data_model <- dwi_data
string_to_match <- "dwi.*AAL.*Frontal.*_dti_fa"
columns_match <- names(data_model)[grep(string_to_match, colnames(data_model))]
for (main_dependent in columns_match) {
    main_predictor <- "pheno_social_isolation"
    covariates_numeric <- c("pheno_age_at_visit", "dwi_white_matter_average_dti_fa")
    #covariates_numeric <- c("pheno_age_at_visit")
    covariates_factor <- c('pheno_msex')
    #interaction <- c('pheno_msex', 'pheno_social_isolation')
    interaction <- c('pheno_social_isolation:pheno_msex')
    model <- run_ols_model(dataframe=data_model,
                  main_dependent = main_dependent,
                  main_predictor = main_predictor,
                  covariates_numeric = covariates_numeric,
                  covariates_factor = covariates_factor,
                  interaction_terms = interaction)
    }
string_to_match <- "regionsurfacestats.*AAL.*Frontal.*Vol"
columns_match <- names(data_model)[grep(string_to_match, colnames(data_model))]
# Out:
# Formula (Full Model): dwi_AAL_Frontal_Mid_Orb_L_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex + pheno_social_isolation:pheno_msex
#
# Significant Relationship between dwi_AAL_Frontal_Mid_Orb_L_dti_fa and pheno_social_isolation with p-value: 0.02808871
#
#                           Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.09057987 0.04113806 -2.201851 0.02808871
#
# RAW Adjusted R-squared: 0.3173917
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.00398406
#
# Formula (Full Model): dwi_AAL_Frontal_Mid_Orb_R_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex + pheno_social_isolation:pheno_msex
#
# Significant Relationship between dwi_AAL_Frontal_Mid_Orb_R_dti_fa and pheno_social_isolation with p-value: 0.01938815
#
#                           Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.09797314 0.04178229 -2.344849 0.01938815
#
# RAW Adjusted R-squared: 0.2958447
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.006262975
#
# Formula (Full Model): dwi_AAL_Frontal_Sup_Medial_L_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex + pheno_social_isolation:pheno_msex
#
# Significant Relationship between dwi_AAL_Frontal_Sup_Medial_L_dti_fa and pheno_social_isolation with p-value: 0.02885597
#
#                           Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation -0.09542993 0.04355184 -2.19118 0.02885597
#
# RAW Adjusted R-squared: 0.2349373
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.004270596

# %% [markdown]
# ## Anatomical MRI Data

# %%
# Run a model
data_model <- anat_data
string_to_match <- "regionsurfacestats.*AAL.*Frontal.*SurfArea*"
columns_match <- names(data_model)[grep(string_to_match, colnames(data_model))]
for (main_dependent in columns_match) {
    main_predictor <- "pheno_social_isolation"
    covariates_numeric <- c("pheno_age_at_visit","brainmeasures_EstimatedTotalIntraCranialVol_eTIV")
    covariates_factor <- c("pheno_msex")
    interaction <- c('pheno_social_isolation:pheno_msex')
    model <- run_ols_model(dataframe=data_model,
                  main_dependent = main_dependent,
                  main_predictor = main_predictor,
                  covariates_numeric = covariates_numeric,
                  covariates_factor = covariates_factor,
                  interaction_terms = interaction,
                  significance_level = 0.05)
    }

# %% [markdown]
# ## fMRI Data

# %%
# Run a model
data_model <- fmri_data
string_to_match <- "bold.*Frontal.*t1t2ratio"
columns_match <- names(data_model)[grep(string_to_match, colnames(data_model))]
for (main_dependent in columns_match) {
    main_predictor <- "pheno_social_isolation"
    covariates_numeric <- c("pheno_age_at_visit")
    covariates_factor <- c("pheno_msex")
    interaction <- c('pheno_social_isolation:pheno_msex')
    model <- run_ols_model(dataframe=data_model,
                  main_dependent = main_dependent,
                  main_predictor = main_predictor,
                  covariates_numeric = covariates_numeric,
                  covariates_factor = covariates_factor,
                  interaction_terms = interaction,
                  significance_level = 0.05)
    }

# %% [markdown]
# # Run Models On Dataset Split By Sex

# %% [markdown]
# ## Subset Dataframes By Sex

# %%
dwi_data_male <- subset(dwi_data, pheno_msex == 1)
anat_data_male <- subset(anat_data, pheno_msex == 1)
fmri_data_male = subset(fmri_data, pheno_msex == 1)

# %%
dwi_data_female <- subset(dwi_data, pheno_msex == 0)
anat_data_female <- subset(anat_data, pheno_msex == 0)
fmri_data_female = subset(fmri_data, pheno_msex == 0)

# %% [markdown]
# ## Male

# %% [markdown]
# ### DWI

# %%
data_model <- dwi_data_male

# %%
# Significant Results Across All DWI Measures
data_model <- dwi_data_male  # Ensure this dataframe is defined

# Loop through all columns in the dataframe
for (main_dependent in colnames(data_model)) {
    # Check if the column is numeric; if not, skip to the next iteration
    if (!is.numeric(data_model[[main_dependent]])) {
        message(sprintf("Skipping column '%s' as it is not numeric", main_dependent))
        next
    }
    
    # Define main predictor
    main_predictor <- "pheno_social_isolation"
    
    # Determine covariates_numeric based on the column name
    covariates_numeric <- c("pheno_age_at_visit", "dwi_neighbor_corr")  # Always include this as the first covariate
    if (grepl("ad$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_ad")
    } else if (grepl("fa$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_dti_fa")
    } else if (grepl("md$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_md")
    } else if (grepl("qa$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_qa")
    } else if (grepl("rd$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_rd")
    } else if (grepl("_length_mm$|_span_mm$|_curl$|_elongation$|_diameter_mm$|_volume_mm3$|_trunk_volume_mm3$|_branch_volume_mm3$|_total_surface_area_mm2$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol")
    }
    
    # Define covariates_factor (if applicable)
    covariates_factor <- NULL  # Adjust if needed for your use case

    # Run the OLS model
    tryCatch({
        model <- run_ols_model(
            dataframe = data_model,
            main_dependent = main_dependent,
            main_predictor = main_predictor,
            covariates_numeric = covariates_numeric,
            covariates_factor = covariates_factor
        )
        # Print or store model results as needed
    }, error = function(e) {
        #message(sprintf("Error running model for column '%s': %s", main_dependent, e$message))
    })
}
# Out:
# Skipping column 'subject' as it is not numeric
# Formula (Full Model): pheno_cogn_global ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between pheno_cogn_global and pheno_social_isolation with p-value: 0.02756177
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1758762 0.07891254 -2.228748 0.02756177
#
# RAW Adjusted R-squared: 0.2208753
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02377719
#
# Formula (Full Model): pheno_cesdsum ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between pheno_cesdsum and pheno_social_isolation with p-value: 6.838025e-07
#
#                         Estimate Std. Error  t value     Pr(>|t|)
# pheno_social_isolation 0.4257457 0.08149963 5.223898 6.838025e-07
#
# RAW Adjusted R-squared: 0.1689519
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.1680578
#
# Formula (Full Model): pheno_r_depres ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between pheno_r_depres and pheno_social_isolation with p-value: 0.02049962
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.2064654 0.08800682 -2.346015 0.02049962
#
# RAW Adjusted R-squared: 0.03094701
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03357238
#
# Formula (Full Model): pheno_soc_net ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between pheno_soc_net and pheno_social_isolation with p-value: 0.00377719
#
#                         Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.257637 0.08734097 -2.949784 0.00377719
#
# RAW Adjusted R-squared: 0.04555507
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.05654152
#
# Formula (Full Model): pheno_tot_adverse_exp ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between pheno_tot_adverse_exp and pheno_social_isolation with p-value: 0.04883196
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1783806  0.0896829 1.989014 0.04883196
#
# RAW Adjusted R-squared: 0.008714349
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02271641
#
# Formula (Full Model): pheno_emotional_neglect ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between pheno_emotional_neglect and pheno_social_isolation with p-value: 0.01822824
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.2141974 0.08953303 2.392384 0.01822824
#
# RAW Adjusted R-squared: 0.03219925
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03628103
#
# Formula (Full Model): pheno_ladder_composite ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between pheno_ladder_composite and pheno_social_isolation with p-value: 0.03605477
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.2006125 0.09450339 -2.122807 0.03605477
#
# RAW Adjusted R-squared: 0.06828951
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02997126
#
# Formula (Full Model): pheno_q40inc ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between pheno_q40inc and pheno_social_isolation with p-value: 0.02685954
#
#                          Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation -0.1893742 0.08455113 -2.23976 0.02685954
#
# RAW Adjusted R-squared: 0.129329
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.027536
#
# Formula (Full Model): pheno_educ ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between pheno_educ and pheno_social_isolation with p-value: 0.009470731
#
#                          Estimate Std. Error   t value    Pr(>|t|)
# pheno_social_isolation -0.2312489 0.08779352 -2.634009 0.009470731
#
# RAW Adjusted R-squared: 0.03563866
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.04404907
#
# Formula (Full Model): brainmeasures_Third_Ventricle_NVoxels ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between brainmeasures_Third_Ventricle_NVoxels and pheno_social_isolation with p-value: 0.03910547
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1646533 0.07899686 2.084301 0.03910547
#
# RAW Adjusted R-squared: 0.2192094
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02008621
#
# Formula (Full Model): brainmeasures_non_WM_hypointensities_NVoxels ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between brainmeasures_non_WM_hypointensities_NVoxels and pheno_social_isolation with p-value: 0.04573994
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1770385 0.08776041 2.017294 0.04573994
#
# RAW Adjusted R-squared: 0.03636592
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0227527
#
# Formula (Full Model): brainmeasures_Third_Ventricle_Volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between brainmeasures_Third_Ventricle_Volume_mm3 and pheno_social_isolation with p-value: 0.03964523
#
#                         Estimate Std. Error t value   Pr(>|t|)
# pheno_social_isolation 0.1654306 0.07959133  2.0785 0.03964523
#
# RAW Adjusted R-squared: 0.2074139
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02024241
#
# Formula (Full Model): brainmeasures_CC_Mid_Anterior_normMean ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between brainmeasures_CC_Mid_Anterior_normMean and pheno_social_isolation with p-value: 0.03579007
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1879678 0.08860018 -2.121529 0.03579007
#
# RAW Adjusted R-squared: 0.01783578
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02644956
#
# Formula (Full Model): brainmeasures_Left_Inf_Lat_Vent_normStdDev ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between brainmeasures_Left_Inf_Lat_Vent_normStdDev and pheno_social_isolation with p-value: 0.0363853
#
#                          Estimate Std. Error   t value  Pr(>|t|)
# pheno_social_isolation -0.1741894 0.08237339 -2.114632 0.0363853
#
# RAW Adjusted R-squared: 0.151037
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02267168
#
# Formula (Full Model): brainmeasures_Right_vessel_normStdDev ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between brainmeasures_Right_vessel_normStdDev and pheno_social_isolation with p-value: 0.007433285
#
#                          Estimate Std. Error   t value    Pr(>|t|)
# pheno_social_isolation -0.2389984 0.08787437 -2.719774 0.007433285
#
# RAW Adjusted R-squared: 0.0338617
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.04754272
#
# Formula (Full Model): brainmeasures_non_WM_hypointensities_normStdDev ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between brainmeasures_non_WM_hypointensities_normStdDev and pheno_social_isolation with p-value: 0.02576456
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1972028 0.08741888 2.255838 0.02576456
#
# RAW Adjusted R-squared: 0.04385155
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0300731
#
# Formula (Full Model): brainmeasures_Right_Putamen_normMin ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between brainmeasures_Right_Putamen_normMin and pheno_social_isolation with p-value: 0.04231316
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1823797  0.0889318 2.050781 0.04231316
#
# RAW Adjusted R-squared: 0.01046977
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02440109
#
# Formula (Full Model): brainmeasures_Right_vessel_normMax ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between brainmeasures_Right_vessel_normMax and pheno_social_isolation with p-value: 0.04043077
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1838237 0.08879614 -2.070176 0.04043077
#
# RAW Adjusted R-squared: 0.01348642
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02493322
#
# Formula (Full Model): brainmeasures_Optic_Chiasm_normMax ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between brainmeasures_Optic_Chiasm_normMax and pheno_social_isolation with p-value: 0.02844843
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1836305 0.08286771 -2.215947 0.02844843
#
# RAW Adjusted R-squared: 0.1408172
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02584436
#
# Formula (Full Model): brainmeasures_Right_vessel_normRange ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between brainmeasures_Right_vessel_normRange and pheno_social_isolation with p-value: 0.007749547
#
#                         Estimate Std. Error   t value    Pr(>|t|)
# pheno_social_isolation -0.237832 0.08791783 -2.705162 0.007749547
#
# RAW Adjusted R-squared: 0.03290566
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.04700004
#
# Formula (Full Model): brainmeasures_non_WM_hypointensities_normRange ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between brainmeasures_non_WM_hypointensities_normRange and pheno_social_isolation with p-value: 0.03525616
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1866178  0.0877046 2.127799 0.03525616
#
# RAW Adjusted R-squared: 0.037591
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02611482
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Sup_L_Range_piallgi ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Frontal_Sup_L_Range_piallgi and pheno_social_isolation with p-value: 0.04782862
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1675857 0.08387385 -1.998069 0.04782862
#
# RAW Adjusted R-squared: 0.1285298
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02021459
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Sup_Orb_L_GausCurv ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Frontal_Sup_Orb_L_GausCurv and pheno_social_isolation with p-value: 0.03333658
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1901009 0.08837607 2.151044 0.03333658
#
# RAW Adjusted R-squared: 0.02279811
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02726388
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Sup_Orb_L_Range_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Frontal_Sup_Orb_L_Range_wgpct and pheno_social_isolation with p-value: 0.03566802
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1877653 0.08844526 2.122955 0.03566802
#
# RAW Adjusted R-squared: 0.02126737
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02640273
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Rolandic_Oper_L_GausCurv ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Rolandic_Oper_L_GausCurv and pheno_social_isolation with p-value: 0.01461437
#
#                         Estimate Std. Error t value   Pr(>|t|)
# pheno_social_isolation 0.2123312  0.0857845 2.47517 0.01461437
#
# RAW Adjusted R-squared: 0.07926942
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03630842
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Med_Orb_R_StdDev_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Frontal_Med_Orb_R_StdDev_wgpct and pheno_social_isolation with p-value: 0.0007133667
#
#                         Estimate Std. Error  t value     Pr(>|t|)
# pheno_social_isolation 0.2904044 0.08374098 3.467889 0.0007133667
#
# RAW Adjusted R-squared: 0.1226135
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.07441759
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Med_Orb_R_Min_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Frontal_Med_Orb_R_Min_wgpct and pheno_social_isolation with p-value: 0.005554764
#
#                          Estimate Std. Error   t value    Pr(>|t|)
# pheno_social_isolation -0.2346661 0.08320299 -2.820405 0.005554764
#
# RAW Adjusted R-squared: 0.1338506
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.04633688
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Med_Orb_R_Range_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Frontal_Med_Orb_R_Range_wgpct and pheno_social_isolation with p-value: 0.001283688
#
#                         Estimate Std. Error  t value    Pr(>|t|)
# pheno_social_isolation 0.2791488 0.08479703 3.291964 0.001283688
#
# RAW Adjusted R-squared: 0.1003447
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.06807642
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Med_Orb_R_SNR_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Frontal_Med_Orb_R_SNR_wgpct and pheno_social_isolation with p-value: 0.005890364
#
#                          Estimate Std. Error  t value    Pr(>|t|)
# pheno_social_isolation -0.2338009 0.08347886 -2.80072 0.005890364
#
# RAW Adjusted R-squared: 0.1346974
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0459082
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Insula_L_GausCurv ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Insula_L_GausCurv and pheno_social_isolation with p-value: 0.02653593
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1946663 0.08674912 2.244015 0.02653593
#
# RAW Adjusted R-squared: 0.05844643
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02922873
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Cingulum_Ant_R_Mean_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Cingulum_Ant_R_Mean_wgpct and pheno_social_isolation with p-value: 0.01091622
#
#                         Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.227171 0.08791495 -2.583986 0.01091622
#
# RAW Adjusted R-squared: 0.06462952
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0421435
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Cingulum_Ant_R_Min_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Cingulum_Ant_R_Min_wgpct and pheno_social_isolation with p-value: 0.01094458
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.2280023 0.08826894 -2.583042 0.01094458
#
# RAW Adjusted R-squared: 0.05708189
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.04244706
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Cingulum_Ant_R_Max_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Cingulum_Ant_R_Max_wgpct and pheno_social_isolation with p-value: 0.01647474
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.2130323 0.08763051 -2.431029 0.01647474
#
# RAW Adjusted R-squared: 0.07067243
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03621354
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Cingulum_Mid_R_GausCurv ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Cingulum_Mid_R_GausCurv and pheno_social_isolation with p-value: 0.01179511
#
#                         Estimate Std. Error t value   Pr(>|t|)
# pheno_social_isolation 0.2177188  0.0852285 2.55453 0.01179511
#
# RAW Adjusted R-squared: 0.09116591
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03862982
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Cingulum_Post_L_StdDev_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Cingulum_Post_L_StdDev_wgpct and pheno_social_isolation with p-value: 0.0479272
#
#                         Estimate Std. Error  t value  Pr(>|t|)
# pheno_social_isolation 0.1695813 0.08491708 1.997022 0.0479272
#
# RAW Adjusted R-squared: 0.09779554
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0207375
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Cingulum_Post_L_Max_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Cingulum_Post_L_Max_wgpct and pheno_social_isolation with p-value: 0.02365644
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1915597 0.08365757 2.289807 0.02365644
#
# RAW Adjusted R-squared: 0.1243605
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02858097
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Cuneus_L_ThickStd ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Cuneus_L_ThickStd and pheno_social_isolation with p-value: 0.01599658
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.2094594 0.08580332 2.441158 0.01599658
#
# RAW Adjusted R-squared: 0.07886547
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03513951
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Occipital_Mid_L_GausCurv ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Occipital_Mid_L_GausCurv and pheno_social_isolation with p-value: 0.02241298
#
#                         Estimate Std. Error t value   Pr(>|t|)
# pheno_social_isolation 0.2039395 0.08824308 2.31111 0.02241298
#
# RAW Adjusted R-squared: 0.02573697
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03253462
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Parietal_Sup_L_GausCurv ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Parietal_Sup_L_GausCurv and pheno_social_isolation with p-value: 0.00632913
#
#                        Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.243409 0.08769447 2.775648 0.00632913
#
# RAW Adjusted R-squared: 0.0378134
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.04962085
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Precuneus_R_CurvInd ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Precuneus_R_CurvInd and pheno_social_isolation with p-value: 0.04907397
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1765991 0.08889041 1.986706 0.04907397
#
# RAW Adjusted R-squared: 0.01139072
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02241103
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Paracentral_Lobule_L_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Paracentral_Lobule_L_SurfArea and pheno_social_isolation with p-value: 0.04930988
#
#                          Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation -0.1676489 0.08447449 -1.98461 0.04930988
#
# RAW Adjusted R-squared: 0.1071756
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02018247
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Paracentral_Lobule_L_Range_piallgi ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Paracentral_Lobule_L_Range_piallgi and pheno_social_isolation with p-value: 0.04200577
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1770709 0.08620536 -2.054059 0.04200577
#
# RAW Adjusted R-squared: 0.07940633
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02297314
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Temporal_Sup_L_GausCurv ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Temporal_Sup_L_GausCurv and pheno_social_isolation with p-value: 0.04583009
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1739463 0.08626394 2.016442 0.04583009
#
# RAW Adjusted R-squared: 0.06894905
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02195876
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Temporal_Mid_L_NumVert ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Temporal_Mid_L_NumVert and pheno_social_isolation with p-value: 0.0472884
#
#                          Estimate Std. Error  t value  Pr(>|t|)
# pheno_social_isolation -0.1738821 0.08681691 -2.00286 0.0472884
#
# RAW Adjusted R-squared: 0.05697428
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02184517
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Temporal_Mid_L_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Temporal_Mid_L_SurfArea and pheno_social_isolation with p-value: 0.02946256
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1896352 0.08613028 -2.201725 0.02946256
#
# RAW Adjusted R-squared: 0.07183195
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02747088
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Temporal_Mid_L_GrayVol ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Temporal_Mid_L_GrayVol and pheno_social_isolation with p-value: 0.007518287
#
#                          Estimate Std. Error   t value    Pr(>|t|)
# pheno_social_isolation -0.2218487 0.08168838 -2.715792 0.007518287
#
# RAW Adjusted R-squared: 0.1650981
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0409457
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Temporal_Mid_L_FoldInd ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Temporal_Mid_L_FoldInd and pheno_social_isolation with p-value: 0.04577463
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1793646 0.08892791 -2.016966 0.04577463
#
# RAW Adjusted R-squared: 0.01055633
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02335203
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Temporal_Inf_L_NumVert ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Temporal_Inf_L_NumVert and pheno_social_isolation with p-value: 0.04861286
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1738195 0.08731009 -1.990829 0.04861286
#
# RAW Adjusted R-squared: 0.04622966
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02174157
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Cerebelum_4_5_L_Mean_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Cerebelum_4_5_L_Mean_wgpct and pheno_social_isolation with p-value: 0.03276006
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1915161 0.08873668 2.158252 0.03276006
#
# RAW Adjusted R-squared: 0.01480714
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0277222
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Cerebelum_4_5_L_StdDev_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Cerebelum_4_5_L_StdDev_wgpct and pheno_social_isolation with p-value: 0.02112102
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.2031537   0.087027 2.334376 0.02112102
#
# RAW Adjusted R-squared: 0.0524047
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03243188
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Cerebelum_4_5_L_Max_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Cerebelum_4_5_L_Max_wgpct and pheno_social_isolation with p-value: 0.008123694
#
#                        Estimate Std. Error  t value    Pr(>|t|)
# pheno_social_isolation 0.230983 0.08591337 2.688557 0.008123694
#
# RAW Adjusted R-squared: 0.07650107
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.04424511
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Cerebelum_4_5_L_Range_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Cerebelum_4_5_L_Range_wgpct and pheno_social_isolation with p-value: 0.04954091
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1724968 0.08700691 1.982565 0.04954091
#
# RAW Adjusted R-squared: 0.052842
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02135158
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Vermis_4_5_GrayVol ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Vermis_4_5_GrayVol and pheno_social_isolation with p-value: 0.002105611
#
#                          Estimate Std. Error   t value    Pr(>|t|)
# pheno_social_isolation -0.2718663 0.08662593 -3.138394 0.002105611
#
# RAW Adjusted R-squared: 0.0611186
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.06391268
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Vermis_4_5_ThickAvg ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_lh_Vermis_4_5_ThickAvg and pheno_social_isolation with p-value: 0.04128864
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1799812 0.08731683 -2.061243 0.04128864
#
# RAW Adjusted R-squared: 0.04608244
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02383858
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Precentral_R_NumVert ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Precentral_R_NumVert and pheno_social_isolation with p-value: 0.04296548
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1794013 0.08775973 -2.044232 0.04296548
#
# RAW Adjusted R-squared: 0.03638074
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02356335
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Precentral_R_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Precentral_R_SurfArea and pheno_social_isolation with p-value: 0.04296024
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1798859 0.08799457 -2.044285 0.04296024
#
# RAW Adjusted R-squared: 0.03121672
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02369122
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Frontal_Mid_R_CurvInd ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Frontal_Mid_R_CurvInd and pheno_social_isolation with p-value: 0.02627359
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1968552   0.087569 2.248001 0.02627359
#
# RAW Adjusted R-squared: 0.04056478
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02991601
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Frontal_Inf_Orb_R_GausCurv ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Frontal_Inf_Orb_R_GausCurv and pheno_social_isolation with p-value: 0.009623824
#
#                         Estimate Std. Error t value    Pr(>|t|)
# pheno_social_isolation 0.2226277 0.08470533 2.62826 0.009623824
#
# RAW Adjusted R-squared: 0.1022893
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.04079579
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Rolandic_Oper_R_Min_piallgi ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Rolandic_Oper_R_Min_piallgi and pheno_social_isolation with p-value: 0.01441665
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.2127134 0.08575308 -2.480533 0.01441665
#
# RAW Adjusted R-squared: 0.08904085
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03638926
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Cingulum_Ant_R_CurvInd ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Cingulum_Ant_R_CurvInd and pheno_social_isolation with p-value: 0.02507351
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1984615 0.08755543 2.266695 0.02507351
#
# RAW Adjusted R-squared: 0.04086197
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03052943
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Cingulum_Mid_R_GausCurv ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Cingulum_Mid_R_GausCurv and pheno_social_isolation with p-value: 0.04993115
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1730411 0.08743298 1.979128 0.04993115
#
# RAW Adjusted R-squared: 0.04354295
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02146105
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Cingulum_Mid_R_Min_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Cingulum_Mid_R_Min_wgpct and pheno_social_isolation with p-value: 0.02207274
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation -0.198735 0.08576811 -2.31712 0.02207274
#
# RAW Adjusted R-squared: 0.07962132
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03093214
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Amygdala_R_ThickStd ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Amygdala_R_ThickStd and pheno_social_isolation with p-value: 0.03097107
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1905206 0.08734111 2.181339 0.03097107
#
# RAW Adjusted R-squared: 0.04555195
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02759267
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Amygdala_R_Mean_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Amygdala_R_Mean_wgpct and pheno_social_isolation with p-value: 0.04659248
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1649084 0.08207269 -2.009296 0.04659248
#
# RAW Adjusted R-squared: 0.1572239
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.01969031
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Amygdala_R_StdDev_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Amygdala_R_StdDev_wgpct and pheno_social_isolation with p-value: 0.003768546
#
#                         Estimate Std. Error  t value    Pr(>|t|)
# pheno_social_isolation 0.2569163 0.08707431 2.950541 0.003768546
#
# RAW Adjusted R-squared: 0.05137414
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.05622936
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Amygdala_R_Min_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Amygdala_R_Min_wgpct and pheno_social_isolation with p-value: 0.03466379
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1772289  0.0830169 -2.134854 0.03466379
#
# RAW Adjusted R-squared: 0.1377207
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02359726
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Amygdala_R_Range_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Amygdala_R_Range_wgpct and pheno_social_isolation with p-value: 0.02402266
#
#                         Estimate Std. Error t value   Pr(>|t|)
# pheno_social_isolation 0.2007804 0.08791812 2.28372 0.02402266
#
# RAW Adjusted R-squared: 0.03289924
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03135919
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Amygdala_R_SNR_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Amygdala_R_SNR_wgpct and pheno_social_isolation with p-value: 0.002298827
#
#                          Estimate Std. Error   t value    Pr(>|t|)
# pheno_social_isolation -0.2525688 0.08118366 -3.111079 0.002298827
#
# RAW Adjusted R-squared: 0.1826042
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.05499243
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Postcentral_R_NumVert ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Postcentral_R_NumVert and pheno_social_isolation with p-value: 0.01992105
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.2076661   0.088101 -2.357137 0.01992105
#
# RAW Adjusted R-squared: 0.02887169
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.034035
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Postcentral_R_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Postcentral_R_SurfArea and pheno_social_isolation with p-value: 0.01849787
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.2105777 0.08826451 -2.385757 0.01849787
#
# RAW Adjusted R-squared: 0.02526374
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03517926
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Postcentral_R_ThickStd ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Postcentral_R_ThickStd and pheno_social_isolation with p-value: 0.04231174
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1734359 0.08457006 2.050796 0.04231174
#
# RAW Adjusted R-squared: 0.1051542
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02206664
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Postcentral_R_FoldInd ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Postcentral_R_FoldInd and pheno_social_isolation with p-value: 0.01778976
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.2113769 0.08804689 -2.400731 0.01778976
#
# RAW Adjusted R-squared: 0.03006439
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03554074
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Postcentral_R_Mean_piallgi ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Postcentral_R_Mean_piallgi and pheno_social_isolation with p-value: 0.044541
#
#                          Estimate Std. Error   t value Pr(>|t|)
# pheno_social_isolation -0.1710843 0.08432303 -2.028915 0.044541
#
# RAW Adjusted R-squared: 0.1191706
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02127986
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Parietal_Sup_R_Max_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Parietal_Sup_R_Max_wgpct and pheno_social_isolation with p-value: 0.02846062
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1946856 0.08786349 2.215774 0.02846062
#
# RAW Adjusted R-squared: 0.03410072
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0290487
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Parietal_Sup_R_Range_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Parietal_Sup_R_Range_wgpct and pheno_social_isolation with p-value: 0.02478149
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.2002003 0.08814104 2.271363 0.02478149
#
# RAW Adjusted R-squared: 0.02798886
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03109754
#
# Formula (Full Model): regionsurfacestats_AAL_rh_SupraMarginal_R_NumVert ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_SupraMarginal_R_NumVert and pheno_social_isolation with p-value: 0.0264656
#
#                         Estimate Std. Error  t value  Pr(>|t|)
# pheno_social_isolation -0.197675 0.08804809 -2.24508 0.0264656
#
# RAW Adjusted R-squared: 0.03003796
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0301463
#
# Formula (Full Model): regionsurfacestats_AAL_rh_SupraMarginal_R_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_SupraMarginal_R_SurfArea and pheno_social_isolation with p-value: 0.03315724
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1901954 0.08832845 -2.153275 0.03315724
#
# RAW Adjusted R-squared: 0.02385109
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02730659
#
# Formula (Full Model): regionsurfacestats_AAL_rh_SupraMarginal_R_ThickStd ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_SupraMarginal_R_ThickStd and pheno_social_isolation with p-value: 0.01590343
#
#                        Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.209151 0.08559955 2.443366 0.01590343
#
# RAW Adjusted R-squared: 0.08323546
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03504887
#
# Formula (Full Model): regionsurfacestats_AAL_rh_SupraMarginal_R_CurvInd ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_SupraMarginal_R_CurvInd and pheno_social_isolation with p-value: 0.04795939
#
#                          Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation -0.1745329 0.08740937 -1.99673 0.04795939
#
# RAW Adjusted R-squared: 0.0440594
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02196405
#
# Formula (Full Model): regionsurfacestats_AAL_rh_SupraMarginal_R_StdDev_piallgi ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_SupraMarginal_R_StdDev_piallgi and pheno_social_isolation with p-value: 0.0204496
#
#                          Estimate Std. Error   t value  Pr(>|t|)
# pheno_social_isolation -0.2081792 0.08869275 -2.347195 0.0204496
#
# RAW Adjusted R-squared: 0.02551378
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03406415
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Precuneus_R_Max_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Precuneus_R_Max_wgpct and pheno_social_isolation with p-value: 0.0162738
#
#                         Estimate Std. Error  t value  Pr(>|t|)
# pheno_social_isolation 0.2117335  0.0869666 2.434653 0.0162738
#
# RAW Adjusted R-squared: 0.05371945
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03586792
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Paracentral_Lobule_R_NumVert ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Paracentral_Lobule_R_NumVert and pheno_social_isolation with p-value: 0.04647231
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1774823 0.08828139 -2.010416 0.04647231
#
# RAW Adjusted R-squared: 0.02489081
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02281585
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Caudate_R_StdDev_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Caudate_R_StdDev_wgpct and pheno_social_isolation with p-value: 0.04481864
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1754486 0.08659507 2.026081 0.04481864
#
# RAW Adjusted R-squared: 0.06178741
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02240887
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Caudate_R_SNR_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Caudate_R_SNR_wgpct and pheno_social_isolation with p-value: 0.02272999
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1991897 0.08639454 -2.305582 0.02272999
#
# RAW Adjusted R-squared: 0.06612777
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03100248
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Pallidum_R_GrayVol ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Pallidum_R_GrayVol and pheno_social_isolation with p-value: 0.03413509
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.2086505 0.09711276 -2.148538 0.03413509
#
# RAW Adjusted R-squared: 0.1123933
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03242199
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Pallidum_R_ThickAvg ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Pallidum_R_ThickAvg and pheno_social_isolation with p-value: 0.03272836
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.2107806 0.09730844 -2.166108 0.03272836
#
# RAW Adjusted R-squared: 0.1088127
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03323522
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Pallidum_R_MeanCurv ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Pallidum_R_MeanCurv and pheno_social_isolation with p-value: 0.01035396
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.2615201  0.1000374 2.614222 0.01035396
#
# RAW Adjusted R-squared: 0.05812531
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.05550548
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Pallidum_R_GausCurv ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Pallidum_R_GausCurv and pheno_social_isolation with p-value: 0.04114055
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.2100711  0.1015133 2.069395 0.04114055
#
# RAW Adjusted R-squared: 0.03012933
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03215657
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Pallidum_R_Mean_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Pallidum_R_Mean_wgpct and pheno_social_isolation with p-value: 0.005714018
#
#                          Estimate Std. Error  t value    Pr(>|t|)
# pheno_social_isolation -0.2670975 0.09451666 -2.82593 0.005714018
#
# RAW Adjusted R-squared: 0.1592155
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.05932949
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Pallidum_R_Min_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Pallidum_R_Min_wgpct and pheno_social_isolation with p-value: 0.005237429
#
#                          Estimate Std. Error   t value    Pr(>|t|)
# pheno_social_isolation -0.2698489 0.09448388 -2.856031 0.005237429
#
# RAW Adjusted R-squared: 0.1597986
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0607399
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Pallidum_R_Max_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Pallidum_R_Max_wgpct and pheno_social_isolation with p-value: 0.006803085
#
#                          Estimate Std. Error  t value    Pr(>|t|)
# pheno_social_isolation -0.2619354 0.09473388 -2.76496 0.006803085
#
# RAW Adjusted R-squared: 0.1553465
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0566942
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Temporal_Sup_R_StdDev_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Temporal_Sup_R_StdDev_wgpct and pheno_social_isolation with p-value: 0.03875493
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1832237 0.08774634 2.088106 0.03875493
#
# RAW Adjusted R-squared: 0.03667479
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02489964
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Temporal_Sup_R_SNR_wgpct ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Temporal_Sup_R_SNR_wgpct and pheno_social_isolation with p-value: 0.04109838
#
#                         Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.169047 0.08193397 -2.063211 0.04109838
#
# RAW Adjusted R-squared: 0.1600705
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02104242
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Temporal_Pole_Sup_R_Mean_piallgi ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Temporal_Pole_Sup_R_Mean_piallgi and pheno_social_isolation with p-value: 0.04611416
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1781268 0.08844776 -2.013921 0.04611416
#
# RAW Adjusted R-squared: 0.03088989
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02295723
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Temporal_Pole_Mid_R_CurvInd ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between regionsurfacestats_AAL_rh_Temporal_Pole_Mid_R_CurvInd and pheno_social_isolation with p-value: 0.01242317
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.2102219 0.08291193 2.535484 0.01242317
#
# RAW Adjusted R-squared: 0.1398999
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03591697
#
# ...
# pheno_social_isolation 0.2241934 0.08242671 2.719913 0.007437589
#
# RAW Adjusted R-squared: 0.1539702
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.04195996
#
# Formula (Full Model): dwi_Cingulum_Frontal_Parietal_R_diameter_mm ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Cingulum_Frontal_Parietal_R_diameter_mm and pheno_social_isolation with p-value: 0.04581275
#
#                         Estimate Std. Error t value   Pr(>|t|)
# pheno_social_isolation 0.1659324 0.08227676 2.01676 0.04581275
#
# RAW Adjusted R-squared: 0.1570455
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0200435
#
# Formula (Full Model): dwi_Cingulum_Frontal_Parietal_R_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Cingulum_Frontal_Parietal_R_volume_mm3 and pheno_social_isolation with p-value: 0.001192253
#
#                         Estimate Std. Error  t value    Pr(>|t|)
# pheno_social_isolation 0.2666421 0.08043397 3.315043 0.001192253
#
# RAW Adjusted R-squared: 0.1943827
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.06238545
#
# Formula (Full Model): dwi_Cingulum_Frontal_Parietal_R_trunk_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Cingulum_Frontal_Parietal_R_trunk_volume_mm3 and pheno_social_isolation with p-value: 0.04637017
#
#                        Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.175533 0.08726377 2.011522 0.04637017
#
# RAW Adjusted R-squared: 0.05176108
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02239184
#
# Formula (Full Model): dwi_Cingulum_Frontal_Parietal_R_total_surface_area_mm2 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Cingulum_Frontal_Parietal_R_total_surface_area_mm2 and pheno_social_isolation with p-value: 0.00354612
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.2449253  0.0824385 2.971006 0.00354612
#
# RAW Adjusted R-squared: 0.1537279
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.05134626
#
# Formula (Full Model): dwi_Cingulum_Parahippocampal_Parietal_L_mean_length_mm ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Cingulum_Parahippocampal_Parietal_L_mean_length_mm and pheno_social_isolation with p-value: 0.04854427
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1713512 0.08603723 1.991594 0.04854427
#
# RAW Adjusted R-squared: 0.07822996
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02119677
#
# Formula (Full Model): dwi_Cingulum_Parahippocampal_Parietal_L_trunk_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Cingulum_Parahippocampal_Parietal_L_trunk_volume_mm3 and pheno_social_isolation with p-value: 0.03579827
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1866066 0.08795526 2.121608 0.03579827
#
# RAW Adjusted R-squared: 0.03667363
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02614589
#
# Formula (Full Model): dwi_Cingulum_Parahippocampal_Parietal_R_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Cingulum_Parahippocampal_Parietal_R_volume_mm3 and pheno_social_isolation with p-value: 0.04369412
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1678847 0.08241055 2.037175 0.04369412
#
# RAW Adjusted R-squared: 0.1543017
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02065131
#
# Formula (Full Model): dwi_Cingulum_Parahippocampal_Parietal_R_total_surface_area_mm2 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Cingulum_Parahippocampal_Parietal_R_total_surface_area_mm2 and pheno_social_isolation with p-value: 0.02098149
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1896894 0.08116134 2.337189 0.02098149
#
# RAW Adjusted R-squared: 0.1797463
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02837475
#
# Formula (Full Model): dwi_Cingulum_Parahippocampal_R_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_dti_fa
#
# Significant Relationship between dwi_Cingulum_Parahippocampal_R_dti_fa and pheno_social_isolation with p-value: 0.01538433
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1938674 0.07893155 2.456145 0.01538433
#
# RAW Adjusted R-squared: 0.2283593
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03010386
#
# Formula (Full Model): dwi_Cingulum_Parolfactory_L_trunk_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Cingulum_Parolfactory_L_trunk_volume_mm3 and pheno_social_isolation with p-value: 0.02168908
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.2000073 0.08605356 2.324219 0.02168908
#
# RAW Adjusted R-squared: 0.0778799
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03146642
#
# Formula (Full Model): dwi_Cingulum_Parolfactory_L_branch_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Cingulum_Parolfactory_L_branch_volume_mm3 and pheno_social_isolation with p-value: 0.04800844
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1737878 0.08704908 -1.996434 0.04800844
#
# RAW Adjusted R-squared: 0.05642123
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02183946
#
# Formula (Full Model): dwi_Cingulum_Parolfactory_R_qa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_qa
#
# Significant Relationship between dwi_Cingulum_Parolfactory_R_qa and pheno_social_isolation with p-value: 0.006157887
#
#                          Estimate Std. Error  t value    Pr(>|t|)
# pheno_social_isolation 0.07563825 0.02715466 2.785461 0.006157887
#
# RAW Adjusted R-squared: 0.9078341
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.004828916
#
# Formula (Full Model): dwi_Parietal_Aslant_Tract_L_trunk_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Parietal_Aslant_Tract_L_trunk_volume_mm3 and pheno_social_isolation with p-value: 0.0136178
#
#                         Estimate Std. Error  t value  Pr(>|t|)
# pheno_social_isolation 0.2106566 0.08420224 2.501793 0.0136178
#
# RAW Adjusted R-squared: 0.1171294
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03599217
#
# Formula (Full Model): dwi_Parietal_Aslant_Tract_L_branch_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Parietal_Aslant_Tract_L_branch_volume_mm3 and pheno_social_isolation with p-value: 0.02639644
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1985564  0.0883913 -2.246334 0.02639644
#
# RAW Adjusted R-squared: 0.02709861
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03051453
#
# Formula (Full Model): dwi_Corticostriatal_Tract_Anterior_L_qa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_qa
#
# Significant Relationship between dwi_Corticostriatal_Tract_Anterior_L_qa and pheno_social_isolation with p-value: 0.0492594
#
#                           Estimate Std. Error   t value  Pr(>|t|)
# pheno_social_isolation -0.03239818 0.01631982 -1.985205 0.0492594
#
# RAW Adjusted R-squared: 0.9667101
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0007589674
#
# Formula (Full Model): dwi_Corticostriatal_Tract_Superior_L_span_mm ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Corticostriatal_Tract_Superior_L_span_mm and pheno_social_isolation with p-value: 0.03224569
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1897945 0.08766648 2.164961 0.03224569
#
# RAW Adjusted R-squared: 0.04298901
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02735312
#
# Formula (Full Model): dwi_Thalamic_Radiation_Anterior_L_qa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_qa
#
# Significant Relationship between dwi_Thalamic_Radiation_Anterior_L_qa and pheno_social_isolation with p-value: 0.04202521
#
#                           Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.04265045 0.02076599 -2.053861 0.04202521
#
# RAW Adjusted R-squared: 0.9461003
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.001344712
#
# Formula (Full Model): dwi_Thalamic_Radiation_Posterior_L_trunk_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Thalamic_Radiation_Posterior_L_trunk_volume_mm3 and pheno_social_isolation with p-value: 0.001730043
#
#                         Estimate Std. Error  t value    Pr(>|t|)
# pheno_social_isolation 0.2674517 0.08356494 3.200525 0.001730043
#
# RAW Adjusted R-squared: 0.1304431
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.06230721
#
# Formula (Full Model): dwi_Thalamic_Radiation_Posterior_R_elongation ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Thalamic_Radiation_Posterior_R_elongation and pheno_social_isolation with p-value: 0.007410215
#
#                          Estimate Std. Error   t value    Pr(>|t|)
# pheno_social_isolation -0.2318314 0.08519442 -2.721203 0.007410215
#
# RAW Adjusted R-squared: 0.09620041
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.04487434
#
# Formula (Full Model): dwi_Thalamic_Radiation_Posterior_R_diameter_mm ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Thalamic_Radiation_Posterior_R_diameter_mm and pheno_social_isolation with p-value: 0.03784214
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1763658 0.08405075 2.098325 0.03784214
#
# RAW Adjusted R-squared: 0.1203034
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02320603
#
# Formula (Full Model): dwi_Thalamic_Radiation_Posterior_R_trunk_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Thalamic_Radiation_Posterior_R_trunk_volume_mm3 and pheno_social_isolation with p-value: 0.03566419
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1794977 0.08454207 2.123176 0.03566419
#
# RAW Adjusted R-squared: 0.1099886
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02420192
#
# Formula (Full Model): dwi_Reticular_Tract_R_qa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_qa
#
# Significant Relationship between dwi_Reticular_Tract_R_qa and pheno_social_isolation with p-value: 0.02944993
#
#                           Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.04356718 0.01978444 -2.202093 0.02944993
#
# RAW Adjusted R-squared: 0.9510752
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.00145986
#
# Formula (Full Model): dwi_Corpus_Callosum_Forceps_Minor_rd ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_rd
#
# Significant Relationship between dwi_Corpus_Callosum_Forceps_Minor_rd and pheno_social_isolation with p-value: 0.04842992
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1283032 0.06438909 1.992623 0.04842992
#
# RAW Adjusted R-squared: 0.4825017
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.01191669
#
# Formula (Full Model): dwi_Corpus_Callosum_Tapetum_span_mm ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Corpus_Callosum_Tapetum_span_mm and pheno_social_isolation with p-value: 0.03201212
#
#                          Estimate Std. Error   t value   Pr(>|t|)
# pheno_social_isolation -0.1873356 0.08641128 -2.167954 0.03201212
#
# RAW Adjusted R-squared: 0.07019767
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02666891
#
# Formula (Full Model): dwi_Corpus_Callosum_Tapetum_curl ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol
#
# Significant Relationship between dwi_Corpus_Callosum_Tapetum_curl and pheno_social_isolation with p-value: 0.002920336
#
#                         Estimate Std. Error  t value    Pr(>|t|)
# pheno_social_isolation 0.2647652 0.08725679 3.034323 0.002920336
#
# RAW Adjusted R-squared: 0.05191285
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.06031828
#
# Formula (Full Model): bold_AAL_Supp_Motor_Area_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between bold_AAL_Supp_Motor_Area_L_t1t2ratio and pheno_social_isolation with p-value: 0.02995733
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1948206 0.08875118 2.195133 0.02995733
#
# RAW Adjusted R-squared: 0.02220762
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02894423
#
# Formula (Full Model): bold_AAL_Supp_Motor_Area_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between bold_AAL_Supp_Motor_Area_R_t1t2ratio and pheno_social_isolation with p-value: 0.02932385
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.1956057 0.08875679 2.203839 0.02932385
#
# RAW Adjusted R-squared: 0.02208397
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.02923822
#
# Formula (Full Model): bold_AAL_Olfactory_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between bold_AAL_Olfactory_R_t1t2ratio and pheno_social_isolation with p-value: 0.04054085
#
#                        Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.183919 0.08888474 2.069185 0.04054085
#
# RAW Adjusted R-squared: 0.01926244
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0249482
#
# Formula (Full Model): bold_AAL_Frontal_Med_Orb_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr
#
# Significant Relationship between bold_AAL_Frontal_Med_Orb_R_t1t2ratio and pheno_social_isolation with p-value: 0.01716408
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.2078511   0.086079 2.414655 0.01716408
#
# RAW Adjusted R-squared: 0.08020125
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.03444296

# %%
options(warn = -1)

# %%
# Significant Results Across All DWI Measures
data_model <- dwi_data_male  # Ensure this dataframe is defined

filtered_columns <- grep("^dwi|^dti", colnames(data_model), value = TRUE)

num_metrics = 0

# Loop through all columns in the dataframe
for (main_dependent in filtered_columns) {
    # Check if the column is numeric; if not, skip to the next iteration
    if (!is.numeric(data_model[[main_dependent]])) {
        message(sprintf("Skipping column '%s' as it is not numeric", main_dependent))
        next
    }
    
    # Define main predictor
    main_predictor <- "pheno_social_isolation"
    
    # Determine covariates_numeric based on the column name
    covariates_numeric <- c("pheno_age_at_visit", "dwi_neighbor_corr")  # Always include this as the first covariate
    if (grepl("ad$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_ad")
    } else if (grepl("fa$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_dti_fa")
    } else if (grepl("md$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_md")
    } else if (grepl("qa$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_qa")
    } else if (grepl("rd$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_rd")
    } else if (grepl("_length_mm$|_span_mm$|_curl$|_elongation$|_diameter_mm$|_volume_mm3$|_trunk_volume_mm3$|_branch_volume_mm3$|_total_surface_area_mm2$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol")
    }
    
    # Define covariates_factor (if applicable)
    covariates_factor <- NULL  # Adjust if needed for your use case

    formula_terms <- c(main_predictor, covariates_numeric, covariates_factor)

    formula_string_full <- paste(main_dependent, "~", paste(formula_terms, collapse = " + "))

    # Subset data to remove rows with missing or invalid values
    complete_data <- data_model[, c(main_dependent, main_predictor, covariates_numeric)]
    complete_data <- complete_data[complete.cases(complete_data), ]

    # Run the OLS model
    tryCatch({
        model <- lm(as.formula(formula_string_full), complete_data)
        model_summary <- summary(model)
        predictor_p_value <- coef(model_summary)[main_predictor, "Pr(>|t|)"]

        if (predictor_p_value <= 0.05) {
            #print(sprintf("Significant result for dependent variable: %s", main_dependent))
            #print(formula_string_full)
            result <- sub("^[^_]*_[^_]*_", "", main_dependent)
            #print(paste(result, ': ', predictor_p_value))
            print(paste(main_dependent, ': ', predictor_p_value))
            num_metrics <- num_metrics + 1
            print(formula_string_full)
        }
    }, error = function(e) {
        message(sprintf("Error running model for column '%s': %s", main_dependent, e$message))
    })
}

print(num_metrics)
# Out:
# [1] "dwi_AAL_Frontal_Sup_Orb_R_ad :  0.0167952436279339"
# [1] "dwi_AAL_Frontal_Sup_Orb_R_ad ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_ad"
# [1] "dwi_AAL_Parietal_Sup_R_ad :  0.0477170432208961"
# [1] "dwi_AAL_Parietal_Sup_R_ad ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_ad"
# [1] "dwi_AAL_Parietal_Inf_R_dti_fa :  0.00721213990142851"
# [1] "dwi_AAL_Parietal_Inf_R_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_dti_fa"
# [1] "dwi_AAL_Cerebelum_9_L_dti_fa :  0.00670838177350307"
# [1] "dwi_AAL_Cerebelum_9_L_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_dti_fa"
# [1] "dwi_AAL_Frontal_Sup_Orb_R_md :  0.017176968627878"
# [1] "dwi_AAL_Frontal_Sup_Orb_R_md ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_md"
# [1] "dwi_AAL_Pallidum_L_qa :  0.0350211037603027"
# [1] "dwi_AAL_Pallidum_L_qa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_qa"
# [1] "dwi_AAL_Pallidum_R_qa :  0.0191299922563721"
# [1] "dwi_AAL_Pallidum_R_qa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_qa"
# [1] "dwi_AAL_Heschl_L_qa :  0.0180331904943996"
# [1] "dwi_AAL_Heschl_L_qa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_qa"
# [1] "dwi_AAL_Temporal_Sup_L_qa :  0.0399607612877629"
# [1] "dwi_AAL_Temporal_Sup_L_qa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_qa"
# [1] "dwi_AAL_Temporal_Inf_L_qa :  0.0246349539791794"
# [1] "dwi_AAL_Temporal_Inf_L_qa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_qa"
# [1] "dwi_AAL_Cerebelum_9_L_qa :  0.0472976618162857"
# [1] "dwi_AAL_Cerebelum_9_L_qa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_qa"
# [1] "dwi_AAL_Frontal_Sup_Orb_R_rd :  0.0198483613321582"
# [1] "dwi_AAL_Frontal_Sup_Orb_R_rd ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_rd"
# [1] "dwi_Arcuate_Fasciculus_L_diameter_mm :  0.0156016911706628"
# [1] "dwi_Arcuate_Fasciculus_L_diameter_mm ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Arcuate_Fasciculus_L_volume_mm3 :  0.0174815830387138"
# [1] "dwi_Arcuate_Fasciculus_L_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Inferior_Fronto_Occipital_Fasciculus_L_branch_volume_mm3 :  0.029642624670227"
# [1] "dwi_Inferior_Fronto_Occipital_Fasciculus_L_branch_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Inferior_Fronto_Occipital_Fasciculus_R_span_mm :  0.00106043468800422"
# [1] "dwi_Inferior_Fronto_Occipital_Fasciculus_R_span_mm ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Inferior_Fronto_Occipital_Fasciculus_R_curl :  0.000906882755088546"
# [1] "dwi_Inferior_Fronto_Occipital_Fasciculus_R_curl ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Inferior_Longitudinal_Fasciculus_L_span_mm :  0.0472731382464859"
# [1] "dwi_Inferior_Longitudinal_Fasciculus_L_span_mm ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Superior_Longitudinal_Fasciculus1_L_md :  0.0307124609854744"
# [1] "dwi_Superior_Longitudinal_Fasciculus1_L_md ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_md"
# [1] "dwi_Superior_Longitudinal_Fasciculus1_L_rd :  0.0182623501832882"
# [1] "dwi_Superior_Longitudinal_Fasciculus1_L_rd ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_rd"
# [1] "dwi_Superior_Longitudinal_Fasciculus1_R_branch_volume_mm3 :  0.0305069985899543"
# [1] "dwi_Superior_Longitudinal_Fasciculus1_R_branch_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Superior_Longitudinal_Fasciculus2_R_diameter_mm :  0.0261789490755808"
# [1] "dwi_Superior_Longitudinal_Fasciculus2_R_diameter_mm ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Superior_Longitudinal_Fasciculus2_R_branch_volume_mm3 :  0.0108377955180576"
# [1] "dwi_Superior_Longitudinal_Fasciculus2_R_branch_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Superior_Longitudinal_Fasciculus2_R_total_surface_area_mm2 :  0.0436403372607324"
# [1] "dwi_Superior_Longitudinal_Fasciculus2_R_total_surface_area_mm2 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Superior_Longitudinal_Fasciculus3_R_ad :  0.0256302715183657"
# [1] "dwi_Superior_Longitudinal_Fasciculus3_R_ad ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_ad"
# [1] "dwi_Superior_Longitudinal_Fasciculus3_R_md :  0.0423388218812808"
# [1] "dwi_Superior_Longitudinal_Fasciculus3_R_md ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_md"
# [1] "dwi_Cingulum_Frontal_Parietal_R_mean_length_mm :  0.00398031172049172"
# [1] "dwi_Cingulum_Frontal_Parietal_R_mean_length_mm ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Cingulum_Frontal_Parietal_R_span_mm :  0.00743758939820511"
# [1] "dwi_Cingulum_Frontal_Parietal_R_span_mm ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Cingulum_Frontal_Parietal_R_diameter_mm :  0.0458127517019732"
# [1] "dwi_Cingulum_Frontal_Parietal_R_diameter_mm ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Cingulum_Frontal_Parietal_R_volume_mm3 :  0.00119225349271801"
# [1] "dwi_Cingulum_Frontal_Parietal_R_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Cingulum_Frontal_Parietal_R_trunk_volume_mm3 :  0.0463701664982735"
# [1] "dwi_Cingulum_Frontal_Parietal_R_trunk_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Cingulum_Frontal_Parietal_R_total_surface_area_mm2 :  0.00354612043007204"
# [1] "dwi_Cingulum_Frontal_Parietal_R_total_surface_area_mm2 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Cingulum_Parahippocampal_Parietal_L_mean_length_mm :  0.0485442708104705"
# [1] "dwi_Cingulum_Parahippocampal_Parietal_L_mean_length_mm ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Cingulum_Parahippocampal_Parietal_L_trunk_volume_mm3 :  0.0357982738793143"
# [1] "dwi_Cingulum_Parahippocampal_Parietal_L_trunk_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Cingulum_Parahippocampal_Parietal_R_volume_mm3 :  0.0436941223972666"
# [1] "dwi_Cingulum_Parahippocampal_Parietal_R_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Cingulum_Parahippocampal_Parietal_R_total_surface_area_mm2 :  0.0209814935119175"
# [1] "dwi_Cingulum_Parahippocampal_Parietal_R_total_surface_area_mm2 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Cingulum_Parahippocampal_R_dti_fa :  0.0153843342060368"
# [1] "dwi_Cingulum_Parahippocampal_R_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_dti_fa"
# [1] "dwi_Cingulum_Parolfactory_L_trunk_volume_mm3 :  0.0216890760142079"
# [1] "dwi_Cingulum_Parolfactory_L_trunk_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Cingulum_Parolfactory_L_branch_volume_mm3 :  0.0480084386984792"
# [1] "dwi_Cingulum_Parolfactory_L_branch_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Cingulum_Parolfactory_R_qa :  0.00615788723893997"
# [1] "dwi_Cingulum_Parolfactory_R_qa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_qa"
# [1] "dwi_Parietal_Aslant_Tract_L_trunk_volume_mm3 :  0.0136177965656922"
# [1] "dwi_Parietal_Aslant_Tract_L_trunk_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Parietal_Aslant_Tract_L_branch_volume_mm3 :  0.0263964432087783"
# [1] "dwi_Parietal_Aslant_Tract_L_branch_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Corticostriatal_Tract_Anterior_L_qa :  0.0492593961509121"
# [1] "dwi_Corticostriatal_Tract_Anterior_L_qa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_qa"
# [1] "dwi_Corticostriatal_Tract_Superior_L_span_mm :  0.0322456864556002"
# [1] "dwi_Corticostriatal_Tract_Superior_L_span_mm ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Thalamic_Radiation_Anterior_L_qa :  0.0420252099488481"
# [1] "dwi_Thalamic_Radiation_Anterior_L_qa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_qa"
# [1] "dwi_Thalamic_Radiation_Posterior_L_trunk_volume_mm3 :  0.00173004276016692"
# [1] "dwi_Thalamic_Radiation_Posterior_L_trunk_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Thalamic_Radiation_Posterior_R_elongation :  0.007410214605974"
# [1] "dwi_Thalamic_Radiation_Posterior_R_elongation ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Thalamic_Radiation_Posterior_R_diameter_mm :  0.0378421400313014"
# [1] "dwi_Thalamic_Radiation_Posterior_R_diameter_mm ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Thalamic_Radiation_Posterior_R_trunk_volume_mm3 :  0.0356641937435197"
# [1] "dwi_Thalamic_Radiation_Posterior_R_trunk_volume_mm3 ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Reticular_Tract_R_qa :  0.0294499299138553"
# [1] "dwi_Reticular_Tract_R_qa ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_qa"
# [1] "dwi_Corpus_Callosum_Forceps_Minor_rd :  0.0484299207735626"
# [1] "dwi_Corpus_Callosum_Forceps_Minor_rd ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + dwi_white_matter_average_rd"
# [1] "dwi_Corpus_Callosum_Tapetum_span_mm :  0.0320121216930924"
# [1] "dwi_Corpus_Callosum_Tapetum_span_mm ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] "dwi_Corpus_Callosum_Tapetum_curl :  0.0029203355322792"
# [1] "dwi_Corpus_Callosum_Tapetum_curl ~ pheno_social_isolation + pheno_age_at_visit + dwi_neighbor_corr + brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol"
# [1] 53

# %%
# Significant Results Across All DWI Measures
data_model <- dwi_data_male  # Ensure this dataframe is defined

filtered_columns <- grep("^dwi|^dti", colnames(data_model), value = TRUE)

num_metrics = 0

# Loop through all columns in the dataframe
for (main_dependent in filtered_columns) {
    # Check if the column is numeric; if not, skip to the next iteration
    if (!is.numeric(data_model[[main_dependent]])) {
        message(sprintf("Skipping column '%s' as it is not numeric", main_dependent))
        next
    }
    
    # Define main predictor
    main_predictor <- "pheno_social_isolation"
    
    # Determine covariates_numeric based on the column name
    covariates_numeric <- c("pheno_age_at_visit", "dwi_neighbor_corr")  # Always include this as the first covariate
    if (grepl("ad$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_ad")
    } else if (grepl("fa$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_dti_fa")
    } else if (grepl("md$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_md")
    } else if (grepl("qa$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_qa")
    } else if (grepl("rd$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_rd")
    } else if (grepl("_length_mm$|_span_mm$|_curl$|_elongation$|_diameter_mm$|_volume_mm3$|_trunk_volume_mm3$|_branch_volume_mm3$|_total_surface_area_mm2$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol")
    }
    
    # Define covariates_factor (if applicable)
    covariates_factor <- NULL  # Adjust if needed for your use case

    formula_terms <- c(main_predictor, covariates_numeric, covariates_factor)

    formula_string_full <- paste(main_dependent, "~", paste(formula_terms, collapse = " + "))

    # Subset data to remove rows with missing or invalid values
    complete_data <- data_model[, c(main_dependent, main_predictor, covariates_numeric)]
    complete_data <- complete_data[complete.cases(complete_data), ]

    # Run the OLS model
    tryCatch({
        model <- lm(as.formula(formula_string_full), complete_data)
        model_summary <- summary(model)
        predictor_p_value <- coef(model_summary)[main_predictor, "Pr(>|t|)"]

        if (0.05 < predictor_p_value & predictor_p_value <= 0.09) {
            #print(sprintf("Significant result for dependent variable: %s", main_dependent))
            #print(formula_string_full)
            result <- sub("^[^_]*_[^_]*_", "", main_dependent)
            print(paste(result, ': ', predictor_p_value))
            #print(paste(main_dependent, ': ', predictor_p_value))
            num_metrics <- num_metrics + 1
            #print(model_summary)
        }
    }, error = function(e) {
        message(sprintf("Error running model for column '%s': %s", main_dependent, e$message))
    })
}

print(num_metrics)
# Out:
# [1] "Rectus_L_ad :  0.0837182051037134"
# [1] "Vermis_8_ad :  0.0617225651467989"
# [1] "Occipital_Inf_R_dti_fa :  0.0631364297903713"
# [1] "Pallidum_L_dti_fa :  0.0888029851848657"
# [1] "Cerebelum_Crus1_L_dti_fa :  0.0878047223553365"
# [1] "Cerebelum_8_L_dti_fa :  0.0880774420127881"
# [1] "Vermis_1_2_dti_fa :  0.0866874409598673"
# [1] "Parietal_Sup_R_md :  0.0515960682315955"
# [1] "Vermis_8_md :  0.0616855971389345"
# [1] "Fusiform_L_qa :  0.0764144740718158"
# [1] "Vermis_1_2_qa :  0.0638737517388227"
# [1] "Parietal_Sup_R_rd :  0.0575610068128989"
# [1] "Vermis_8_rd :  0.0629799113566381"
# [1] "Fasciculus_L_elongation :  0.0529876185923954"
# [1] "Fasciculus_L_trunk_volume_mm3 :  0.0584414384012361"
# [1] "Fasciculus_R_mean_length_mm :  0.0516858209767957"
# [1] "Fronto_Occipital_Fasciculus_L_curl :  0.0769506245110427"
# [1] "Fronto_Occipital_Fasciculus_R_mean_length_mm :  0.0617900416225809"
# [1] "Longitudinal_Fasciculus_R_qa :  0.0543767434917025"
# [1] "Longitudinal_Fasciculus1_L_dti_fa :  0.0624488573281416"
# [1] "Longitudinal_Fasciculus1_L_qa :  0.0540474365947695"
# [1] "Longitudinal_Fasciculus3_R_rd :  0.065257259686907"
# [1] "Frontal_Parahippocampal_R_mean_length_mm :  0.0691064377556201"
# [1] "Parahippocampal_Parietal_L_span_mm :  0.050694175225425"
# [1] "Parahippocampal_Parietal_L_volume_mm3 :  0.0812524005886091"
# [1] "Parahippocampal_R_curl :  0.0612546474675493"
# [1] "Parolfactory_L_span_mm :  0.0640633479258597"
# [1] "Parolfactory_R_ad :  0.0777167575355175"
# [1] "Parolfactory_R_dti_fa :  0.0635514401520307"
# [1] "Parolfactory_R_mean_length_mm :  0.0830868433208435"
# [1] "Parolfactory_R_trunk_volume_mm3 :  0.0878260893105844"
# [1] "Aslant_Tract_R_elongation :  0.0553099631027563"
# [1] "Aslant_Tract_R_diameter_mm :  0.0694384045306629"
# [1] "Aslant_Tract_L_qa :  0.0635724147519382"
# [1] "Aslant_Tract_R_qa :  0.0635509268681749"
# [1] "Tract_R_branch_volume_mm3 :  0.0505445798230695"
# [1] "Tract_Anterior_L_mean_length_mm :  0.0622027482704778"
# [1] "Tract_Posterior_R_ad :  0.0885218410533056"
# [1] "Tract_Superior_L_mean_length_mm :  0.0556716371368021"
# [1] "Tract_Superior_L_elongation :  0.0544398794966775"
# [1] "Tract_Superior_R_dti_fa :  0.0642786463701268"
# [1] "Tract_Superior_R_qa :  0.0636823983264106"
# [1] "Tract_Superior_R_rd :  0.0696976353930663"
# [1] "Tract_Superior_R_trunk_volume_mm3 :  0.0619822277320786"
# [1] "Radiation_Posterior_R_curl :  0.0786043939990634"
# [1] "Radiation_Posterior_R_volume_mm3 :  0.0697529972917636"
# [1] "Tract_L_qa :  0.0614428349147736"
# [1] "Radiation_L_branch_volume_mm3 :  0.0600465589210136"
# [1] "L_diameter_mm :  0.0765749639784197"
# [1] "L_branch_volume_mm3 :  0.0666372918583338"
# [1] "Callosum_Forceps_Minor_dti_fa :  0.0790502106169264"
# [1] "Callosum_Forceps_Minor_md :  0.0642373130422389"
# [1] "Callosum_Body_branch_volume_mm3 :  0.0714656624608733"
# [1] "Callosum_Body_total_surface_area_mm2 :  0.0566107451154088"
# [1] "Callosum_Tapetum_branch_volume_mm3 :  0.052511192660698"
# [1] "Callosum_Tapetum_total_surface_area_mm2 :  0.0564719080229716"
# [1] "Callosum_Forceps_Major_span_mm :  0.0593548933823064"
# [1] 57

# %% [markdown]
# ### Anatomical MRI

# %%
# Significant Results Across All DWI Measures
data_model <- anat_data_male  # Ensure this dataframe is defined

# Select relevant columns
filtered_columns <- grep("^regionsurfacestats|^brainmeasures", colnames(data_model), value = TRUE)

num_metrics <- 0

# Loop through all columns in the dataframe
for (main_dependent in filtered_columns) {
    # Check if the column is numeric; if not, skip to the next iteration
    if (!is.numeric(data_model[[main_dependent]])) {
        message(sprintf("Skipping column '%s' as it is not numeric", main_dependent))
        next
    }
    
    # Define main predictor
    main_predictor <- "pheno_social_isolation"
    
    # Determine covariates_numeric based on the column name
    covariates_numeric <- c("pheno_age_at_visit", "brainmeasures_EstimatedTotalIntraCranialVol_eTIV")
    
    # Define covariates_factor (if applicable)
    covariates_factor <- NULL  # Adjust if needed for your use case

    formula_terms <- c(main_predictor, covariates_numeric, covariates_factor)
    formula_string_full <- paste(main_dependent, "~", paste(formula_terms, collapse = " + "))
    
    # Subset data to remove rows with missing or invalid values
    complete_data <- data_model[, c(main_dependent, main_predictor, covariates_numeric)]
    
    # Ensure all columns are numeric and contain finite values
    complete_data <- complete_data[complete.cases(complete_data), ]  # Remove rows with NA
    complete_data <- complete_data[apply(complete_data, 1, function(row) all(is.finite(row))), ]  # Remove NaN/Inf
    
    # Ensure the dependent variable has no NA/NaN/Inf
    if (!all(is.finite(complete_data[[main_dependent]]))) {
        message(sprintf("Skipping column '%s' due to NA/NaN/Inf in dependent variable", main_dependent))
        next
    }
    
    # Run the OLS model
    tryCatch({
        if (nrow(complete_data) > 0) {  # Ensure there is enough data
            model <- lm(as.formula(formula_string_full), complete_data)
            model_summary <- summary(model)
            predictor_p_value <- coef(model_summary)[main_predictor, "Pr(>|t|)"]

            if (!is.na(predictor_p_value) && predictor_p_value <= 0.05) {
                #result <- sub("^[^_]*_[^_]*_", "", main_dependent)
                print(paste(main_dependent, ': ', predictor_p_value))
                num_metrics <- num_metrics + 1
            }
        } else {
            message(sprintf("Insufficient data for column '%s'", main_dependent))
        }
    }, error = function(e) {
        message(sprintf("Error running model for column '%s': %s", main_dependent, e$message))
    })
}

print(num_metrics)
# Out:
# [1] "brainmeasures_Third_Ventricle_NVoxels :  0.0136293503590011"
# [1] "brainmeasures_CSF_NVoxels :  0.0135837759666407"
# [1] "brainmeasures_CC_Anterior_NVoxels :  0.0328131191650158"
# [1] "brainmeasures_Third_Ventricle_Volume_mm3 :  0.0139720941441333"
# [1] "brainmeasures_CSF_Volume_mm3 :  0.0250236107329253"
# [1] "brainmeasures_CC_Anterior_Volume_mm3 :  0.0458862768743499"
# [1] "brainmeasures_Right_vessel_normMean :  0.0424381988414895"
# [1] "brainmeasures_CC_Mid_Anterior_normMean :  0.0260342370884672"
# [1] "brainmeasures_Left_Inf_Lat_Vent_normStdDev :  0.0288627888140739"
# [1] "brainmeasures_Right_Thalamus_normStdDev :  0.024336824089706"
# [1] "brainmeasures_Right_Hippocampus_normStdDev :  0.03386559721473"
# [1] "brainmeasures_Right_vessel_normStdDev :  0.0300122140005364"
# [1] "brainmeasures_Right_Thalamus_normMin :  0.00906318846298391"
# [1] "brainmeasures_Right_Putamen_normMin :  0.0479886985509286"
# [1] "brainmeasures_Right_Hippocampus_normMin :  0.0463455955155262"
# [1] "brainmeasures_Right_vessel_normMax :  0.0287207065989856"
# [1] "brainmeasures_Right_Thalamus_normRange :  0.0188059373577857"
# [1] "brainmeasures_Right_vessel_normRange :  0.035804160089257"
# [1] "regionsurfacestats_AAL_lh_Frontal_Sup_Orb_L_Max_wgpct :  0.0316042882380916"
# [1] "regionsurfacestats_AAL_lh_Frontal_Sup_Orb_L_Range_wgpct :  0.0321068159925857"
# [1] "regionsurfacestats_AAL_lh_Frontal_Inf_Orb_L_GausCurv :  0.0260046350371222"
# [1] "regionsurfacestats_AAL_lh_Olfactory_R_NumVert :  0.0346357213862874"
# [1] "regionsurfacestats_AAL_lh_Olfactory_R_StdDev_wgpct :  0.00480296299663409"
# [1] "regionsurfacestats_AAL_lh_Olfactory_R_Range_wgpct :  0.00988720190842381"
# [1] "regionsurfacestats_AAL_lh_Frontal_Med_Orb_R_StdDev_wgpct :  0.0150620970634154"
# [1] "regionsurfacestats_AAL_lh_Frontal_Med_Orb_R_Min_wgpct :  0.0398238272490845"
# [1] "regionsurfacestats_AAL_lh_Frontal_Med_Orb_R_Range_wgpct :  0.0247685239089774"
# [1] "regionsurfacestats_AAL_lh_Frontal_Med_Orb_R_SNR_wgpct :  0.0120452398332671"
# [1] "regionsurfacestats_AAL_lh_Insula_L_StdDev_wgpct :  0.0186785380845768"
# [1] "regionsurfacestats_AAL_lh_Insula_L_SNR_wgpct :  0.0350594157563218"
# [1] "regionsurfacestats_AAL_lh_Cingulum_Ant_R_Mean_wgpct :  0.0417336385884709"
# [1] "regionsurfacestats_AAL_lh_Cingulum_Ant_R_Min_wgpct :  0.045952753854462"
# [1] "regionsurfacestats_AAL_lh_Cingulum_Post_L_ThickAvg :  0.0253837860549779"
# [1] "regionsurfacestats_AAL_lh_Cingulum_Post_L_ThickStd :  0.0423467147454509"
# [1] "regionsurfacestats_AAL_lh_Cingulum_Post_L_StdDev_wgpct :  0.00410222190721174"
# [1] "regionsurfacestats_AAL_lh_Cingulum_Post_L_Max_wgpct :  0.0100497914365419"
# [1] "regionsurfacestats_AAL_lh_Cingulum_Post_L_Range_wgpct :  0.0452272060315941"
# [1] "regionsurfacestats_AAL_lh_Cingulum_Post_L_SNR_wgpct :  0.0246833167204759"
# [1] "regionsurfacestats_AAL_lh_Cingulum_Post_R_CurvInd :  0.0125045155851893"
# [1] "regionsurfacestats_AAL_lh_Cingulum_Post_R_StdDev_wgpct :  0.0268763802954887"
# [1] "regionsurfacestats_AAL_lh_Cingulum_Post_R_Max_wgpct :  0.0241994359075358"
# [1] "regionsurfacestats_AAL_lh_Cuneus_L_ThickStd :  0.0383556098164016"
# [1] "regionsurfacestats_AAL_lh_Lingual_R_NumVert :  0.0413704045736188"
# [1] "regionsurfacestats_AAL_lh_Occipital_Mid_L_GausCurv :  0.0303154021709213"
# [1] "regionsurfacestats_AAL_lh_Precuneus_R_FoldInd :  0.0436234943961238"
# [1] "regionsurfacestats_AAL_lh_Precuneus_R_CurvInd :  0.0331163565264573"
# [1] "regionsurfacestats_AAL_lh_Paracentral_Lobule_L_NumVert :  0.0244194840533469"
# [1] "regionsurfacestats_AAL_lh_Paracentral_Lobule_L_SurfArea :  0.0341228161160059"
# [1] "regionsurfacestats_AAL_lh_Paracentral_Lobule_L_GrayVol :  0.040371843470619"
# [1] "regionsurfacestats_AAL_lh_Paracentral_Lobule_L_Range_piallgi :  0.0383037888587826"
# [1] "regionsurfacestats_AAL_lh_Paracentral_Lobule_R_NumVert :  0.037394935398488"
# [1] "regionsurfacestats_AAL_lh_Thalamus_L_GrayVol :  0.0229987448014683"
# [1] "regionsurfacestats_AAL_lh_Temporal_Mid_L_GrayVol :  0.0207629307796081"
# [1] "regionsurfacestats_AAL_lh_Cerebelum_4_5_L_Mean_wgpct :  0.0344090688578062"
# [1] "regionsurfacestats_AAL_lh_Cerebelum_4_5_L_StdDev_wgpct :  0.0311727962870889"
# [1] "regionsurfacestats_AAL_lh_Cerebelum_4_5_L_Max_wgpct :  0.00971698057734111"
# [1] "regionsurfacestats_AAL_lh_Vermis_4_5_GrayVol :  0.00983465250811611"
# [1] "regionsurfacestats_AAL_rh_Frontal_Sup_Orb_R_SNR_wgpct :  0.0212588748993178"
# [1] "regionsurfacestats_AAL_rh_Cingulum_Mid_R_GausCurv :  0.0459800797371923"
# [1] "regionsurfacestats_AAL_rh_Cingulum_Mid_R_Min_wgpct :  0.0139796994215627"
# [1] "regionsurfacestats_AAL_rh_Cingulum_Mid_R_Range_wgpct :  0.00972319327667102"
# [1] "regionsurfacestats_AAL_rh_Cingulum_Post_R_ThickAvg :  0.018381410024052"
# [1] "regionsurfacestats_AAL_rh_Amygdala_R_ThickStd :  0.00377598421304457"
# [1] "regionsurfacestats_AAL_rh_Amygdala_R_Mean_wgpct :  0.00832732601342148"
# [1] "regionsurfacestats_AAL_rh_Amygdala_R_StdDev_wgpct :  0.00677832265596021"
# [1] "regionsurfacestats_AAL_rh_Amygdala_R_Min_wgpct :  0.00451589194970837"
# [1] "regionsurfacestats_AAL_rh_Amygdala_R_SNR_wgpct :  0.000969416774060577"
# [1] "regionsurfacestats_AAL_rh_Occipital_Sup_R_MeanCurv :  0.0148431023113143"
# [1] "regionsurfacestats_AAL_rh_Occipital_Sup_R_GausCurv :  0.0153150703255711"
# [1] "regionsurfacestats_AAL_rh_Fusiform_R_MeanCurv :  0.0298691580479942"
# [1] "regionsurfacestats_AAL_rh_Parietal_Sup_R_Range_wgpct :  0.0396066894565348"
# [1] "regionsurfacestats_AAL_rh_SupraMarginal_R_MeanCurv :  0.0290613745865037"
# [1] "regionsurfacestats_AAL_rh_SupraMarginal_R_CurvInd :  0.015303170914444"
# [1] "regionsurfacestats_AAL_rh_SupraMarginal_R_StdDev_piallgi :  0.0346036498869388"
# [1] "regionsurfacestats_AAL_rh_Precuneus_R_Max_wgpct :  0.00349811894825198"
# [1] "regionsurfacestats_AAL_rh_Caudate_R_StdDev_wgpct :  0.0209610033583908"
# [1] "regionsurfacestats_AAL_rh_Caudate_R_SNR_wgpct :  0.0138616640132864"
# [1] "regionsurfacestats_AAL_rh_Pallidum_R_GrayVol :  0.0153627009968392"
# [1] "regionsurfacestats_AAL_rh_Pallidum_R_ThickAvg :  0.0132216065663628"
# [1] "regionsurfacestats_AAL_rh_Pallidum_R_MeanCurv :  0.00615308434122386"
# [1] "regionsurfacestats_AAL_rh_Pallidum_R_GausCurv :  0.027176502558805"
# [1] "regionsurfacestats_AAL_rh_Pallidum_R_Mean_wgpct :  0.00249351070815019"
# [1] "regionsurfacestats_AAL_rh_Pallidum_R_Min_wgpct :  0.00245876337494384"
# [1] "regionsurfacestats_AAL_rh_Pallidum_R_Max_wgpct :  0.00288456861337016"
# [1] "regionsurfacestats_AAL_rh_Thalamus_R_Range_piallgi :  0.0409524593106584"
# [1] "regionsurfacestats_AAL_rh_Temporal_Mid_R_GrayVol :  0.0323810151661441"
# [1] "regionsurfacestats_AAL_rh_Temporal_Mid_R_Max_wgpct :  0.00961250498374469"
# [1] "regionsurfacestats_AAL_rh_Temporal_Mid_R_Range_wgpct :  0.0106253580741284"
# [1] "regionsurfacestats_AAL_rh_Temporal_Pole_Mid_R_CurvInd :  0.0245596211789862"
# [1] 89

# %%
# Significant Results Across All DWI Measures
data_model <- anat_data_male  # Ensure this dataframe is defined

# Select relevant columns
filtered_columns <- grep("^regionsurfacestats|^brainmeasures", colnames(data_model), value = TRUE)

num_metrics <- 0

# Loop through all columns in the dataframe
for (main_dependent in filtered_columns) {
    # Check if the column is numeric; if not, skip to the next iteration
    if (!is.numeric(data_model[[main_dependent]])) {
        message(sprintf("Skipping column '%s' as it is not numeric", main_dependent))
        next
    }
    
    # Define main predictor
    main_predictor <- "pheno_social_isolation"
    
    # Determine covariates_numeric based on the column name
    covariates_numeric <- c("pheno_age_at_visit", "brainmeasures_EstimatedTotalIntraCranialVol_eTIV")
    
    # Define covariates_factor (if applicable)
    covariates_factor <- NULL  # Adjust if needed for your use case

    formula_terms <- c(main_predictor, covariates_numeric, covariates_factor)
    formula_string_full <- paste(main_dependent, "~", paste(formula_terms, collapse = " + "))
    
    # Subset data to remove rows with missing or invalid values
    complete_data <- data_model[, c(main_dependent, main_predictor, covariates_numeric)]
    
    # Ensure all columns are numeric and contain finite values
    complete_data <- complete_data[complete.cases(complete_data), ]  # Remove rows with NA
    complete_data <- complete_data[apply(complete_data, 1, function(row) all(is.finite(row))), ]  # Remove NaN/Inf
    
    # Ensure the dependent variable has no NA/NaN/Inf
    if (!all(is.finite(complete_data[[main_dependent]]))) {
        message(sprintf("Skipping column '%s' due to NA/NaN/Inf in dependent variable", main_dependent))
        next
    }
    
    # Run the OLS model
    tryCatch({
        if (nrow(complete_data) > 0) {  # Ensure there is enough data
            model <- lm(as.formula(formula_string_full), complete_data)
            model_summary <- summary(model)
            predictor_p_value <- coef(model_summary)[main_predictor, "Pr(>|t|)"]

            if (!is.na(predictor_p_value) && (0.05 < predictor_p_value & predictor_p_value <= 0.09)) {
                #result <- sub("^[^_]*_[^_]*_", "", main_dependent)
                print(paste(main_dependent, ': ', predictor_p_value))
                num_metrics <- num_metrics + 1
            }
        } else {
            message(sprintf("Insufficient data for column '%s'", main_dependent))
        }
    }, error = function(e) {
        message(sprintf("Error running model for column '%s': %s", main_dependent, e$message))
    })
}

print(num_metrics)
# Out:
# [1] "brainmeasures_Left_Caudate_NVoxels :  0.0597664980631146"
# [1] "brainmeasures_Right_Inf_Lat_Vent_NVoxels :  0.0593796389267966"
# [1] "brainmeasures_Right_vessel_NVoxels :  0.0807636197501193"
# [1] "brainmeasures_Right_Inf_Lat_Vent_Volume_mm3 :  0.0648705732073857"
# [1] "brainmeasures_Right_vessel_Volume_mm3 :  0.0845299299687882"
# [1] "brainmeasures_CC_Central_Volume_mm3 :  0.0667503667642428"
# [1] "brainmeasures_Right_Inf_Lat_Vent_normMean :  0.0823652214886302"
# [1] "brainmeasures_Third_Ventricle_normStdDev :  0.0530696568789841"
# [1] "brainmeasures_Right_VentralDC_normStdDev :  0.0670047075239609"
# [1] "brainmeasures_CC_Posterior_normStdDev :  0.0829376455748664"
# [1] "brainmeasures_Right_vessel_normMin :  0.0807927273406665"
# [1] "brainmeasures_Right_Hippocampus_normRange :  0.0546151119906774"
# [1] "regionsurfacestats_AAL_lh_Frontal_Sup_Orb_L_GausCurv :  0.0663845976913079"
# [1] "regionsurfacestats_AAL_lh_Frontal_Inf_Orb_L_CurvInd :  0.0758261042575029"
# [1] "regionsurfacestats_AAL_lh_Frontal_Inf_Orb_L_StdDev_wgpct :  0.0753122893387154"
# [1] "regionsurfacestats_AAL_lh_Frontal_Inf_Orb_L_SNR_wgpct :  0.0696803407396149"
# [1] "regionsurfacestats_AAL_lh_Supp_Motor_Area_L_CurvInd :  0.0797552545503675"
# [1] "regionsurfacestats_AAL_lh_Olfactory_R_Min_wgpct :  0.0549629876042988"
# [1] "regionsurfacestats_AAL_lh_Olfactory_R_SNR_wgpct :  0.0524394332129995"
# [1] "regionsurfacestats_AAL_lh_Rectus_R_CurvInd :  0.0721347057760078"
# [1] "regionsurfacestats_AAL_lh_Insula_L_ThickStd :  0.0780629724301181"
# [1] "regionsurfacestats_AAL_lh_Cingulum_Ant_R_Max_wgpct :  0.0500765650708877"
# [1] "regionsurfacestats_AAL_lh_Cingulum_Mid_L_Max_wgpct :  0.0892776289724192"
# [1] "regionsurfacestats_AAL_lh_Cingulum_Mid_R_GausCurv :  0.0887296271359681"
# [1] "regionsurfacestats_AAL_lh_Occipital_Mid_L_MeanCurv :  0.0693566424110911"
# [1] "regionsurfacestats_AAL_lh_Paracentral_Lobule_L_Max_piallgi :  0.0787275000306942"
# [1] "regionsurfacestats_AAL_lh_Paracentral_Lobule_R_SurfArea :  0.0841849380011211"
# [1] "regionsurfacestats_AAL_lh_Thalamus_L_ThickAvg :  0.0882426811595827"
# [1] "regionsurfacestats_AAL_lh_Temporal_Mid_L_SurfArea :  0.0791136398055392"
# [1] "regionsurfacestats_AAL_lh_Temporal_Mid_L_FoldInd :  0.0856602482792188"
# [1] "regionsurfacestats_AAL_lh_Cerebelum_4_5_L_Range_wgpct :  0.0783530040389863"
# [1] "regionsurfacestats_AAL_lh_Cerebelum_6_L_CurvInd :  0.0534852028086911"
# [1] "regionsurfacestats_AAL_rh_Precentral_R_Range_piallgi :  0.0562447302966615"
# [1] "regionsurfacestats_AAL_rh_Frontal_Mid_R_FoldInd :  0.0578052733464104"
# [1] "regionsurfacestats_AAL_rh_Frontal_Mid_R_CurvInd :  0.0626792879546002"
# [1] "regionsurfacestats_AAL_rh_Frontal_Mid_Orb_R_StdDev_piallgi :  0.0809849926235404"
# [1] "regionsurfacestats_AAL_rh_Frontal_Inf_Oper_R_StdDev_piallgi :  0.0702770175345733"
# [1] "regionsurfacestats_AAL_rh_Rolandic_Oper_R_Min_piallgi :  0.0796821862303617"
# [1] "regionsurfacestats_AAL_rh_Olfactory_R_GrayVol :  0.0610481094911706"
# [1] "regionsurfacestats_AAL_rh_Rectus_R_ThickAvg :  0.0669292153257437"
# [1] "regionsurfacestats_AAL_rh_Insula_R_CurvInd :  0.0873959863963223"
# [1] "regionsurfacestats_AAL_rh_Cingulum_Ant_R_SurfArea :  0.0715465762168335"
# [1] "regionsurfacestats_AAL_rh_Cingulum_Mid_R_Max_wgpct :  0.0808454542652641"
# [1] "regionsurfacestats_AAL_rh_ParaHippocampal_R_StdDev_wgpct :  0.0518635962348171"
# [1] "regionsurfacestats_AAL_rh_Amygdala_R_Range_wgpct :  0.0670950920326767"
# [1] "regionsurfacestats_AAL_rh_Occipital_Sup_R_CurvInd :  0.0898842431810871"
# [1] "regionsurfacestats_AAL_rh_Fusiform_R_Max_wgpct :  0.0521098685260132"
# [1] "regionsurfacestats_AAL_rh_Fusiform_R_Range_wgpct :  0.0668165150701887"
# [1] "regionsurfacestats_AAL_rh_Postcentral_R_ThickStd :  0.0682885970557322"
# [1] "regionsurfacestats_AAL_rh_Postcentral_R_Range_piallgi :  0.0880396800332786"
# [1] "regionsurfacestats_AAL_rh_Parietal_Sup_R_Max_wgpct :  0.0639032494785594"
# [1] "regionsurfacestats_AAL_rh_Parietal_Sup_R_StdDev_piallgi :  0.0652019596050584"
# [1] "regionsurfacestats_AAL_rh_Parietal_Inf_R_GrayVol :  0.0793254111506478"
# [1] "regionsurfacestats_AAL_rh_SupraMarginal_R_NumVert :  0.0550268384834392"
# [1] "regionsurfacestats_AAL_rh_SupraMarginal_R_SurfArea :  0.062894854356752"
# [1] "regionsurfacestats_AAL_rh_SupraMarginal_R_ThickStd :  0.0705358036115803"
# [1] "regionsurfacestats_AAL_rh_Precuneus_R_StdDev_wgpct :  0.0831412632461583"
# [1] "regionsurfacestats_AAL_rh_Precuneus_R_StdDev_piallgi :  0.083926074256425"
# [1] "regionsurfacestats_AAL_rh_Precuneus_R_Min_piallgi :  0.0850636783883566"
# [1] "regionsurfacestats_AAL_rh_Caudate_R_Min_wgpct :  0.0673094889589122"
# [1] "regionsurfacestats_AAL_rh_Caudate_R_Range_wgpct :  0.0594617552296051"
# [1] "regionsurfacestats_AAL_rh_Thalamus_R_StdDev_piallgi :  0.0637097913794561"
# [1] "regionsurfacestats_AAL_rh_Heschl_R_ThickStd :  0.0628322929734495"
# [1] "regionsurfacestats_AAL_rh_Temporal_Sup_R_ThickAvg :  0.0689227916521531"
# [1] "regionsurfacestats_AAL_rh_Temporal_Sup_R_StdDev_wgpct :  0.062973334570588"
# [1] "regionsurfacestats_AAL_rh_Temporal_Sup_R_Min_wgpct :  0.0888445490446552"
# [1] "regionsurfacestats_AAL_rh_Temporal_Pole_Sup_R_CurvInd :  0.0604368754694139"
# [1] "regionsurfacestats_AAL_rh_Temporal_Pole_Sup_R_Min_wgpct :  0.0517527242966113"
# [1] "regionsurfacestats_AAL_rh_Temporal_Mid_R_NumVert :  0.0739144201272631"
# [1] "regionsurfacestats_AAL_rh_Temporal_Mid_R_SurfArea :  0.0777707263531897"
# [1] "regionsurfacestats_AAL_rh_Temporal_Mid_R_Min_wgpct :  0.0897737101382179"
# [1] "regionsurfacestats_AAL_rh_Temporal_Pole_Mid_R_Max_wgpct :  0.0839370033747289"
# [1] "regionsurfacestats_AAL_rh_Temporal_Inf_R_MeanCurv :  0.0611497362186646"
# [1] 73

# %% [markdown]
# ### fMRI

# %%
# Run a model
data_model <- fmri_data_male
string_to_match <- "bold.*Frontal.*t1t2ratio"
columns_match <- names(data_model)[grep(string_to_match, colnames(data_model))]
p_values_list <- list()
for (main_dependent in columns_match) {
    main_predictor <- "pheno_social_isolation"
    covariates_numeric <- c("pheno_age_at_visit")
    covariates_factor <- NULL
    model <- run_ols_model(dataframe=data_model,
                  main_dependent = main_dependent,
                  main_predictor = main_predictor,
                  covariates_numeric = covariates_numeric,
                  covariates_factor = covariates_factor,
                  significance_level = 0.05)
    p_values_list[[main_dependent]] <- model$p_value_main
    
    }
# Out:
# Formula (Full Model): bold_AAL_Frontal_Med_Orb_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Med_Orb_R_t1t2ratio and pheno_social_isolation with p-value: 0.01572837
#
#                         Estimate Std. Error  t value   Pr(>|t|)
# pheno_social_isolation 0.2413736 0.09821818 2.457525 0.01572837
#
# RAW Adjusted R-squared: 0.08894666
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.04591187

# %%
# Significant Results Across All DWI Measures
data_model <- fmri_data_male  # Ensure this dataframe is defined

# Select relevant columns
filtered_columns <- grep("^bold", colnames(data_model), value = TRUE)

num_metrics <- 0

# Loop through all columns in the dataframe
for (main_dependent in filtered_columns) {
    # Check if the column is numeric; if not, skip to the next iteration
    if (!is.numeric(data_model[[main_dependent]])) {
        message(sprintf("Skipping column '%s' as it is not numeric", main_dependent))
        next
    }
    
    # Define main predictor
    main_predictor <- "pheno_social_isolation"
    
    # Determine covariates_numeric based on the column name
    covariates_numeric <- c("pheno_age_at_visit")
    
    # Define covariates_factor (if applicable)
    covariates_factor <- NULL  # Adjust if needed for your use case

    formula_terms <- c(main_predictor, covariates_numeric, covariates_factor)
    formula_string_full <- paste(main_dependent, "~", paste(formula_terms, collapse = " + "))
    
    # Subset data to remove rows with missing or invalid values
    complete_data <- data_model[, c(main_dependent, main_predictor, covariates_numeric)]
    
    # Ensure only complete and finite cases are used
    complete_data <- complete_data[complete.cases(complete_data), ]
    complete_data <- complete_data[sapply(complete_data, function(x) all(is.finite(x))), ]
    
    # Run the OLS model
    tryCatch({
        if (nrow(complete_data) > 0) {  # Ensure there is enough data
            model <- lm(as.formula(formula_string_full), complete_data)
            model_summary <- summary(model)
            predictor_p_value <- coef(model_summary)[main_predictor, "Pr(>|t|)"]

            if (!is.na(predictor_p_value) && predictor_p_value <= 0.05) {
                #result <- sub("^[^_]*_[^_]*_", "", main_dependent)
                print(paste(main_dependent, ': ', predictor_p_value))
                num_metrics <- num_metrics + 1
            }
        } else {
            message(sprintf("Insufficient data for column '%s'", main_dependent))
        }
    }, error = function(e) {
        message(sprintf("Error running model for column '%s': %s", main_dependent, e$message))
    })
}

print(num_metrics)
# Out:
# [1] "bold_AAL_Rectus_R_alff :  0.0467636550452386"
# [1] "bold_AAL_Cerebelum_3_L_alff :  0.039378930509796"
# [1] "bold_AAL_Vermis_1_2_alff :  0.015547643211689"
# [1] "bold_AAL_Frontal_Med_Orb_R_t1t2ratio :  0.0157283685109375"
# [1] "bold_AAL_Cingulum_Ant_R_t1t2ratio :  0.0196303833884097"
# [1] 5

# %%
# Significant Results Across All DWI Measures
data_model <- fmri_data_male  # Ensure this dataframe is defined

# Select relevant columns
filtered_columns <- grep("^bold", colnames(data_model), value = TRUE)

num_metrics <- 0

# Loop through all columns in the dataframe
for (main_dependent in filtered_columns) {
    # Check if the column is numeric; if not, skip to the next iteration
    if (!is.numeric(data_model[[main_dependent]])) {
        message(sprintf("Skipping column '%s' as it is not numeric", main_dependent))
        next
    }
    
    # Define main predictor
    main_predictor <- "pheno_social_isolation"
    
    # Determine covariates_numeric based on the column name
    covariates_numeric <- c("pheno_age_at_visit")
    
    # Define covariates_factor (if applicable)
    covariates_factor <- NULL  # Adjust if needed for your use case

    formula_terms <- c(main_predictor, covariates_numeric, covariates_factor)
    formula_string_full <- paste(main_dependent, "~", paste(formula_terms, collapse = " + "))
    
    # Subset data to remove rows with missing or invalid values
    complete_data <- data_model[, c(main_dependent, main_predictor, covariates_numeric)]
    
    # Ensure only complete and finite cases are used
    complete_data <- complete_data[complete.cases(complete_data), ]
    complete_data <- complete_data[sapply(complete_data, function(x) all(is.finite(x))), ]
    
    # Run the OLS model
    tryCatch({
        if (nrow(complete_data) > 0) {  # Ensure there is enough data
            model <- lm(as.formula(formula_string_full), complete_data)
            model_summary <- summary(model)
            predictor_p_value <- coef(model_summary)[main_predictor, "Pr(>|t|)"]

            if (!is.na(predictor_p_value) && (0.05 < predictor_p_value & predictor_p_value <= 0.09)) {
                #result <- sub("^[^_]*_[^_]*_", "", main_dependent)
                print(paste(main_dependent, ': ', predictor_p_value))
                num_metrics <- num_metrics + 1
            }
        } else {
            message(sprintf("Insufficient data for column '%s'", main_dependent))
        }
    }, error = function(e) {
        message(sprintf("Error running model for column '%s': %s", main_dependent, e$message))
    })
}

print(num_metrics)
# Out:
# [1] "bold_AAL_Occipital_Sup_R_alff :  0.0614737767316619"
# [1] "bold_AAL_Frontal_Inf_Tri_L_t1t2ratio :  0.0631217411280773"
# [1] 2

# %% [markdown]
# ## Females

# %% [markdown]
# ### DWI

# %%
# Run a model
data_model <- dwi_data_female
string_to_match <- "dwi.*AAL.*Frontal.*_dti_fa"
columns_match <- names(data_model)[grep(string_to_match, colnames(data_model))]
for (main_dependent in columns_match) {
    main_predictor <- "pheno_social_isolation"
    covariates_numeric <- c("pheno_age_at_visit", "dwi_white_matter_average_dti_fa")
    #covariates_numeric <- c("pheno_age_at_visit")
    covariates_factor <- NULL
    model <- run_ols_model(dataframe=data_model,
                  main_dependent = main_dependent,
                  main_predictor = main_predictor,
                  covariates_numeric = covariates_numeric,
                  covariates_factor = covariates_factor)
    }

# %%
# Significant Results Across All DWI Measures
data_model <- dwi_data_female  # Ensure this dataframe is defined

filtered_columns <- grep("^dwi|^dti", colnames(data_model), value = TRUE)

num_metrics = 0

# Loop through all columns in the dataframe
for (main_dependent in filtered_columns) {
    # Check if the column is numeric; if not, skip to the next iteration
    if (!is.numeric(data_model[[main_dependent]])) {
        message(sprintf("Skipping column '%s' as it is not numeric", main_dependent))
        next
    }
    
    # Define main predictor
    main_predictor <- "pheno_social_isolation"
    
    # Determine covariates_numeric based on the column name
    covariates_numeric <- c("pheno_age_at_visit", "dwi_neighbor_corr")  # Always include this as the first covariate
    if (grepl("ad$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_ad")
    } else if (grepl("fa$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_dti_fa")
    } else if (grepl("md$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_md")
    } else if (grepl("qa$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_qa")
    } else if (grepl("rd$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "dwi_white_matter_average_rd")
    } else if (grepl("_length_mm$|_span_mm$|_curl$|_elongation$|_diameter_mm$|_volume_mm3$|_trunk_volume_mm3$|_branch_volume_mm3$|_total_surface_area_mm2$", main_dependent)) {
        covariates_numeric <- c(covariates_numeric, "brainmeasures_CerebralWhiteMatter_CerebralWhiteMatterVol")
    }
    
    # Define covariates_factor (if applicable)
    covariates_factor <- NULL  # Adjust if needed for your use case

    formula_terms <- c(main_predictor, covariates_numeric, covariates_factor)

    formula_string_full <- paste(main_dependent, "~", paste(formula_terms, collapse = " + "))

    # Subset data to remove rows with missing or invalid values
    complete_data <- data_model[, c(main_dependent, main_predictor, covariates_numeric)]
    complete_data <- complete_data[complete.cases(complete_data), ]

    # Run the OLS model
    tryCatch({
        model <- lm(as.formula(formula_string_full), complete_data)
        model_summary <- summary(model)
        predictor_p_value <- coef(model_summary)[main_predictor, "Pr(>|t|)"]

        if (predictor_p_value <= 0.05) {
            #print(sprintf("Significant result for dependent variable: %s", main_dependent))
            #print(formula_string_full)
            result <- sub("^[^_]*_[^_]*_", "", main_dependent)
            print(paste(result, ': ', predictor_p_value))
            #print(paste(main_dependent, ': ', predictor_p_value))
            num_metrics <- num_metrics + 1
            #print(model_summary)
        }
    }, error = function(e) {
        message(sprintf("Error running model for column '%s': %s", main_dependent, e$message))
    })
}

print(num_metrics)
# Out:
# [1] "Rolandic_Oper_L_ad :  0.000219867732744627"
# [1] "Rolandic_Oper_R_ad :  0.0101987735793022"
# [1] "Olfactory_L_ad :  0.00430546812641179"
# [1] "Rectus_L_ad :  0.0441438112563414"
# [1] "Insula_L_ad :  0.00079120996892748"
# [1] "Insula_R_ad :  0.000161794804269096"
# [1] "Hippocampus_L_ad :  0.000285452956418966"
# [1] "Hippocampus_R_ad :  0.000433587112299852"
# [1] "ParaHippocampal_L_ad :  0.00387929371026727"
# [1] "ParaHippocampal_R_ad :  0.00541941081479455"
# [1] "Amygdala_L_ad :  0.00117804713869709"
# [1] "Amygdala_R_ad :  0.00296445525391933"
# [1] "Fusiform_L_ad :  0.026519776195904"
# [1] "Fusiform_R_ad :  0.00736783545518802"
# [1] "Thalamus_L_ad :  0.00695311963280466"
# [1] "Thalamus_R_ad :  0.00598550790545657"
# [1] "Heschl_L_ad :  0.000161536303734801"
# [1] "Heschl_R_ad :  0.000570928695999992"
# [1] "Temporal_Sup_L_ad :  0.00298614012706195"
# [1] "Temporal_Sup_R_ad :  0.00257464788862759"
# [1] "Temporal_Pole_Sup_L_ad :  0.0116102891439683"
# [1] "Temporal_Pole_Sup_R_ad :  0.0363133178741129"
# [1] "Temporal_Mid_L_ad :  0.00287659937037535"
# [1] "Temporal_Mid_R_ad :  0.000626681473863996"
# [1] "Temporal_Pole_Mid_L_ad :  0.0234486532326699"
# [1] "Temporal_Pole_Mid_R_ad :  0.028911752673737"
# [1] "Temporal_Inf_L_ad :  0.0106304212772941"
# [1] "Temporal_Inf_R_ad :  0.0195986205868669"
# [1] "Cerebelum_Crus2_L_ad :  0.0320735974736097"
# [1] "Cerebelum_3_R_ad :  0.0377447844013659"
# [1] "Frontal_Mid_Orb_L_dti_fa :  0.0116920731978418"
# [1] "Frontal_Mid_Orb_R_dti_fa :  0.00506056714300566"
# [1] "Frontal_Inf_Tri_L_dti_fa :  0.0253510784054526"
# [1] "Olfactory_L_dti_fa :  0.0205679392687309"
# [1] "Frontal_Sup_Medial_L_dti_fa :  0.00893151162030747"
# [1] "Insula_R_dti_fa :  0.00840182134559017"
# [1] "Cingulum_Ant_L_dti_fa :  0.00136734327594186"
# [1] "Hippocampus_L_dti_fa :  0.02871307328731"
# [1] "Calcarine_L_dti_fa :  0.00771939843136709"
# [1] "Postcentral_R_dti_fa :  0.0185806042956535"
# [1] "Cerebelum_Crus2_L_dti_fa :  0.0249420872989758"
# [1] "Cerebelum_6_R_dti_fa :  0.010205168234352"
# [1] "Cerebelum_7b_L_dti_fa :  0.0094008475801242"
# [1] "Vermis_6_dti_fa :  0.0131685703596097"
# [1] "Rolandic_Oper_L_md :  0.000353885516299769"
# [1] "Rolandic_Oper_R_md :  0.0151992155322841"
# [1] "Olfactory_L_md :  0.00275047185318962"
# [1] "Insula_L_md :  0.0015493261718149"
# [1] "Insula_R_md :  0.000277858865552139"
# [1] "Cingulum_Post_R_md :  0.00749358135050142"
# [1] "Hippocampus_L_md :  0.000951755072313273"
# [1] "Hippocampus_R_md :  0.00121415819509278"
# [1] "ParaHippocampal_L_md :  0.00560782645920468"
# [1] "ParaHippocampal_R_md :  0.0125686988488215"
# [1] "Amygdala_L_md :  0.00168395287408715"
# [1] "Amygdala_R_md :  0.00535784775162776"
# [1] "Calcarine_R_md :  0.0398932300235652"
# [1] "Fusiform_L_md :  0.034063545809571"
# [1] "Fusiform_R_md :  0.00757159274030285"
# [1] "Thalamus_L_md :  0.00830753525461585"
# [1] "Thalamus_R_md :  0.0109494440950793"
# [1] "Heschl_L_md :  0.000362459409949211"
# [1] "Heschl_R_md :  0.000456890484581401"
# [1] "Temporal_Sup_L_md :  0.00332299640054449"
# [1] "Temporal_Sup_R_md :  0.00404216664111365"
# [1] "Temporal_Pole_Sup_L_md :  0.013988513261465"
# [1] "Temporal_Pole_Sup_R_md :  0.0368354157601868"
# [1] "Temporal_Mid_L_md :  0.00404356013366895"
# [1] "Temporal_Mid_R_md :  0.000595012884946658"
# [1] "Temporal_Pole_Mid_L_md :  0.0380585022059036"
# [1] "Temporal_Pole_Mid_R_md :  0.0387038834311908"
# [1] "Temporal_Inf_L_md :  0.0231745256626928"
# [1] "Temporal_Inf_R_md :  0.0332653120746452"
# [1] "Cerebelum_Crus2_L_md :  0.0345138060611777"
# [1] "Cerebelum_3_R_md :  0.0407767324780257"
# [1] "Vermis_1_2_md :  0.0413346553669902"
# [1] "Frontal_Mid_Orb_L_qa :  0.0154403378656927"
# [1] "Caudate_R_qa :  0.0085208942355657"
# [1] "Rolandic_Oper_L_rd :  0.000471461027292139"
# [1] "Rolandic_Oper_R_rd :  0.0185687312968749"
# [1] "Olfactory_L_rd :  0.00225383597393471"
# [1] "Insula_L_rd :  0.00233138150889114"
# [1] "Insula_R_rd :  0.000358511364804366"
# [1] "Cingulum_Post_R_rd :  0.00623396159935263"
# [1] "Hippocampus_L_rd :  0.00169782083562542"
# [1] "Hippocampus_R_rd :  0.00196387938449892"
# [1] "ParaHippocampal_L_rd :  0.00696801823888067"
# [1] "ParaHippocampal_R_rd :  0.0190501502415587"
# [1] "Amygdala_L_rd :  0.00213695166876426"
# [1] "Amygdala_R_rd :  0.00805581893565746"
# [1] "Calcarine_R_rd :  0.0297052172374587"
# [1] "Fusiform_L_rd :  0.039187742465881"
# [1] "Fusiform_R_rd :  0.00810826834695877"
# [1] "Thalamus_L_rd :  0.00946216001055132"
# [1] "Thalamus_R_rd :  0.0163482644788995"
# [1] "Heschl_L_rd :  0.00058927308011293"
# [1] "Heschl_R_rd :  0.000426202202380085"
# [1] "Temporal_Sup_L_rd :  0.00375184897378914"
# [1] "Temporal_Sup_R_rd :  0.00547635806191106"
# [1] "Temporal_Pole_Sup_L_rd :  0.0153645909167387"
# [1] "Temporal_Pole_Sup_R_rd :  0.0372939015806327"
# [1] "Temporal_Mid_L_rd :  0.00543572458944963"
# [1] "Temporal_Mid_R_rd :  0.000654449139895611"
# [1] "Temporal_Pole_Mid_L_rd :  0.0496031479089535"
# [1] "Temporal_Pole_Mid_R_rd :  0.0449637807072917"
# [1] "Temporal_Inf_L_rd :  0.036487480855124"
# [1] "Temporal_Inf_R_rd :  0.0457650200012887"
# [1] "Cerebelum_Crus2_L_rd :  0.0357039600713739"
# [1] "Cerebelum_3_R_rd :  0.0414623227813751"
# [1] "Vermis_1_2_rd :  0.0397207232885665"
# [1] "Fasciculus_L_curl :  0.017667345944853"
# [1] "Fasciculus_L_elongation :  0.0137622948533342"
# [1] "Fasciculus_L_diameter_mm :  0.00600724915147347"
# [1] "Fasciculus_L_volume_mm3 :  0.010568472292078"
# [1] "Fasciculus_L_total_surface_area_mm2 :  0.00699026121864694"
# [1] "Fasciculus_R_diameter_mm :  0.0264615470803608"
# [1] "Fronto_Occipital_Fasciculus_L_elongation :  0.0374981174431129"
# [1] "Fronto_Occipital_Fasciculus_L_diameter_mm :  0.0147136639426194"
# [1] "Fronto_Occipital_Fasciculus_L_volume_mm3 :  0.012571735120555"
# [1] "Fronto_Occipital_Fasciculus_L_trunk_volume_mm3 :  0.0462530510208548"
# [1] "Fronto_Occipital_Fasciculus_L_total_surface_area_mm2 :  0.0430059336924141"
# [1] "Longitudinal_Fasciculus_L_elongation :  0.0318766104518751"
# [1] "Longitudinal_Fasciculus_R_mean_length_mm :  0.0116811461018907"
# [1] "Longitudinal_Fasciculus_R_span_mm :  0.0239466889694417"
# [1] "Longitudinal_Fasciculus_R_branch_volume_mm3 :  0.0368749868798308"
# [1] "Longitudinal_Fasciculus2_R_qa :  0.0137102502502762"
# [1] "Longitudinal_Fasciculus2_R_mean_length_mm :  0.00661926684526612"
# [1] "Longitudinal_Fasciculus2_R_elongation :  0.00790049558939864"
# [1] "Frontal_Parahippocampal_L_volume_mm3 :  0.0303816237825147"
# [1] "Frontal_Parahippocampal_L_branch_volume_mm3 :  0.0462192287806645"
# [1] "Frontal_Parahippocampal_L_total_surface_area_mm2 :  0.0325041258643562"
# [1] "Frontal_Parietal_R_ad :  0.0203109466797989"
# [1] "Frontal_Parietal_R_md :  0.0468568721545629"
# [1] "Parahippocampal_Parietal_L_mean_length_mm :  0.0305430200231792"
# [1] "Parahippocampal_Parietal_L_span_mm :  0.0297803015289849"
# [1] "Parolfactory_R_diameter_mm :  0.0202468784021624"
# [1] "Aslant_Tract_L_dti_fa :  0.00186035928221629"
# [1] "Aslant_Tract_L_qa :  0.0126340166489557"
# [1] "Aslant_Tract_L_trunk_volume_mm3 :  0.0364576862907654"
# [1] "Aslant_Tract_R_dti_fa :  0.0118795921641619"
# [1] "Aslant_Tract_R_qa :  0.0451131443896314"
# [1] "Aslant_Tract_R_elongation :  0.0394183207063723"
# [1] "Aslant_Tract_R_diameter_mm :  0.0164281514916421"
# [1] "Aslant_Tract_R_volume_mm3 :  0.0129747102740053"
# [1] "Aslant_Tract_R_trunk_volume_mm3 :  0.0452316205348596"
# [1] "Aslant_Tract_L_span_mm :  0.0486862747130236"
# [1] "Aslant_Tract_L_diameter_mm :  0.025510506251959"
# [1] "Aslant_Tract_L_volume_mm3 :  0.0172210525551887"
# [1] "Tract_L_diameter_mm :  0.0392709862880848"
# [1] "Tract_L_volume_mm3 :  0.0283588052750964"
# [1] "Tract_L_trunk_volume_mm3 :  0.00727093098210831"
# [1] "Tract_R_trunk_volume_mm3 :  0.0238817500066929"
# [1] "Tract_Posterior_L_dti_fa :  0.0384360738680051"
# [1] "Tract_Posterior_R_trunk_volume_mm3 :  0.0181016432116331"
# [1] "Radiation_Anterior_R_ad :  0.0388396982700653"
# [1] "Radiation_Superior_L_diameter_mm :  0.0478668707056818"
# [1] "Radiation_Superior_L_volume_mm3 :  0.0293466240138268"
# [1] "Radiation_Superior_L_branch_volume_mm3 :  0.0143717210708249"
# [1] "Radiation_Superior_L_total_surface_area_mm2 :  0.0468086884751276"
# [1] "Radiation_Superior_R_trunk_volume_mm3 :  0.00485462710561581"
# [1] "Radiation_R_mean_length_mm :  0.00675256616093738"
# [1] "Radiation_R_curl :  0.0291236845823518"
# [1] "L_mean_length_mm :  0.012611139849586"
# [1] "L_elongation :  0.047487638421365"
# [1] "R_branch_volume_mm3 :  0.0291988624281254"
# [1] "Callosum_Tapetum_mean_length_mm :  0.0157872882930486"
# [1] "Callosum_Tapetum_total_surface_area_mm2 :  0.0352522344261323"
# [1] "corr :  0.020468458552648"
# [1] 168

# %% [markdown]
# ### Anatomical MRI

# %%
# Run a model
data_model <- anat_data_female
string_to_match <- "regionsurfacestats.*AAL.*Frontal.*SurfArea*"
columns_match <- names(data_model)[grep(string_to_match, colnames(data_model))]
for (main_dependent in columns_match) {
    main_predictor <- "pheno_social_isolation"
    covariates_numeric <- c("pheno_age_at_visit","brainmeasures_EstimatedTotalIntraCranialVol_eTIV")
    covariates_factor <- NULL
    model <- run_ols_model(dataframe=data_model,
                  main_dependent = main_dependent,
                  main_predictor = main_predictor,
                  covariates_numeric = covariates_numeric,
                  covariates_factor = covariates_factor,
                  significance_level = 0.05)
    }

# %% [markdown]
# ### fMRI

# %%
# Run a model
data_model <- fmri_data_female
string_to_match <- "bold.*Frontal.*t1t2ratio"
columns_match <- names(data_model)[grep(string_to_match, colnames(data_model))]
p_values_list <- list()
for (main_dependent in columns_match) {
    main_predictor <- "pheno_social_isolation"
    covariates_numeric <- c("pheno_age_at_visit")
    covariates_factor <- NULL
    model <- run_ols_model(dataframe=data_model,
                  main_dependent = main_dependent,
                  main_predictor = main_predictor,
                  covariates_numeric = covariates_numeric,
                  covariates_factor = covariates_factor,
                  significance_level = 0.05)
    p_values_list[[main_dependent]] <- model$p_value_main
    
    }

# %%
filtered_p_values <- p_values_list[grep("Med", names(p_values_list))]
print(filtered_p_values)
# Out:
# $bold_AAL_Frontal_Sup_Medial_L_t1t2ratio
# [1] 0.2018895
#
# $bold_AAL_Frontal_Sup_Medial_R_t1t2ratio
# [1] 0.1952962
#
# $bold_AAL_Frontal_Med_Orb_L_t1t2ratio
# [1] 0.6601218
#
# $bold_AAL_Frontal_Med_Orb_R_t1t2ratio
# [1] 0.8970751

# %%
# Run a model
data_model <- fmri_data_female
string_to_match <- "bold.*Frontal.*t1t2ratio"
columns_match <- names(data_model)[grep(string_to_match, colnames(data_model))]
for (main_dependent in columns_match) {
    main_predictor <- "pheno_social_isolation"
    covariates_numeric <- c("pheno_age_at_visit")
    covariates_factor <- NULL
    run_ols_model <- run_ols_model_FDR(dataframe=data_model,
                  main_dependent = main_dependent,
                  main_predictor = main_predictor,
                  covariates_numeric = covariates_numeric,
                  covariates_factor = covariates_factor, 
                  interaction_terms = NULL, significance_level = 1.0, delta_rsq_threshold = 0.0000)
    }
# Out:
# Formula (Full Model): bold_AAL_Frontal_Sup_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Sup_L_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 1
#
#                            Estimate Std. Error    t value  Pr(>|t|)
# pheno_social_isolation -0.009249295 0.05964156 -0.1550814 0.8768643
# Formula (Full Model): bold_AAL_Frontal_Sup_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Sup_R_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 1
#
#                           Estimate Std. Error   t value  Pr(>|t|)
# pheno_social_isolation 0.008431606 0.05918923 0.1424517 0.8868215
# Formula (Full Model): bold_AAL_Frontal_Sup_Orb_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Sup_Orb_L_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 1
#
#                            Estimate Std. Error    t value  Pr(>|t|)
# pheno_social_isolation -0.006316989 0.05966876 -0.1058676 0.9157601
# Formula (Full Model): bold_AAL_Frontal_Sup_Orb_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Sup_Orb_R_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 1
#
#                            Estimate Std. Error   t value  Pr(>|t|)
# pheno_social_isolation -0.009878949 0.05644693 -0.175013 0.8611907
# Formula (Full Model): bold_AAL_Frontal_Mid_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Mid_L_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 0.5662539
#
#                          Estimate Std. Error  t value  Pr(>|t|)
# pheno_social_isolation 0.07841972 0.05952801 1.317358 0.1887513
#
# RAW Adjusted R-squared: -0.0003481046
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.002510884
#
# Formula (Full Model): bold_AAL_Frontal_Mid_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Mid_R_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 1
#
#                          Estimate Std. Error   t value  Pr(>|t|)
# pheno_social_isolation 0.02151614 0.05906749 0.3642637 0.7159247
# Formula (Full Model): bold_AAL_Frontal_Mid_Orb_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Mid_Orb_L_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 0.855284
#
#                           Estimate Std. Error    t value  Pr(>|t|)
# pheno_social_isolation -0.03241308  0.0570235 -0.5684161 0.5701894
# Formula (Full Model): bold_AAL_Frontal_Mid_Orb_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Mid_Orb_R_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 0.4506612
#
#                          Estimate Std. Error  t value  Pr(>|t|)
# pheno_social_isolation 0.06161144  0.0593943 1.037329 0.3004408
#
# RAW Adjusted R-squared: 0.004140668
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0002584867
#
# Formula (Full Model): bold_AAL_Frontal_Inf_Oper_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Inf_Oper_L_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 0.7522182
#
#                           Estimate Std. Error    t value  Pr(>|t|)
# pheno_social_isolation -0.04288066 0.05959757 -0.7195035 0.4724062
# Formula (Full Model): bold_AAL_Frontal_Inf_Oper_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Inf_Oper_R_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 0.338565
#
#                           Estimate Std. Error   t value Pr(>|t|)
# pheno_social_isolation -0.07044867 0.05802787 -1.214049  0.22571
#
# RAW Adjusted R-squared: 0.04943554
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.001537497
#
# Formula (Full Model): bold_AAL_Frontal_Inf_Tri_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Inf_Tri_L_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 0.7031105
#
#                          Estimate Std. Error   t value  Pr(>|t|)
# pheno_social_isolation 0.04173826 0.05753214 0.7254772 0.4687403
# Formula (Full Model): bold_AAL_Frontal_Inf_Tri_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Inf_Tri_R_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 0.9340672
#
#                           Estimate Std. Error    t value  Pr(>|t|)
# pheno_social_isolation -0.02933803 0.05956539 -0.4925348 0.6227115
# Formula (Full Model): bold_AAL_Frontal_Inf_Orb_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Inf_Orb_L_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 1
#
#                           Estimate Std. Error    t value  Pr(>|t|)
# pheno_social_isolation -0.02230756 0.05766892 -0.3868213 0.6991703
# Formula (Full Model): bold_AAL_Frontal_Inf_Orb_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Inf_Orb_R_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 1
#
#                          Estimate Std. Error   t value  Pr(>|t|)
# pheno_social_isolation 0.01689879 0.05510198 0.3066822 0.7593039
# Formula (Full Model): bold_AAL_Frontal_Sup_Medial_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Sup_Medial_L_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 0.6056684
#
#                           Estimate Std. Error   t value  Pr(>|t|)
# pheno_social_isolation -0.07616269 0.05954557 -1.279066 0.2018895
#
# RAW Adjusted R-squared: -0.0009383315
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.002172715
#
# Formula (Full Model): bold_AAL_Frontal_Sup_Medial_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Sup_Medial_R_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 0.5858887
#
#                           Estimate Std. Error   t value  Pr(>|t|)
# pheno_social_isolation -0.07728214 0.05953734 -1.298045 0.1952962
#
# RAW Adjusted R-squared: -0.0006615702
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.00233916
#
# Formula (Full Model): bold_AAL_Frontal_Med_Orb_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Med_Orb_L_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 0.9901826
#
#                           Estimate Std. Error    t value  Pr(>|t|)
# pheno_social_isolation -0.02625908 0.05965333 -0.4401947 0.6601218
# Formula (Full Model): bold_AAL_Frontal_Med_Orb_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit
#
# Significant Relationship between bold_AAL_Frontal_Med_Orb_R_t1t2ratio and pheno_social_isolation with FDR corrected p-value: 1
#
#                           Estimate Std. Error   t value  Pr(>|t|)
# pheno_social_isolation 0.007294897 0.05634439 0.1294698 0.8970751

# %%
# Run a model
data_model <- fmri_data_female
string_to_match <- "bold.*Frontal.*t1t2ratio"
columns_match <- names(data_model)[grep(string_to_match, colnames(data_model))]
for (main_dependent in columns_match) {
    main_predictor <- "pheno_social_isolation"
    covariates_numeric <- c("pheno_age_at_visit")
    covariates_factor <- NULL
    model <- run_ols_model(dataframe=data_model,
                  main_dependent = main_dependent,
                  main_predictor = main_predictor,
                  covariates_numeric = covariates_numeric,
                  covariates_factor = covariates_factor,
                  significance_level = 0.05)
    }

# %% [markdown]
# # Visuals

# %%
install.packages("kableExtra")
# Out:
# also installing the dependency ‘svglite’

# %%
library(kableExtra)

# Create a data frame for the table
df <- data.frame(
  Term = "pheno_social_isolation",
  Estimate = 0.2413736,
  Std_Error = 0.09821818,
  t_value = 2.457525,
  Pr = 0.01572837
)

# Format the table
kable(df, format = "html", caption = "Model Summary") %>%
  kable_styling(full_width = F) %>%
  add_header_above(c(" " = 1, "Coefficients" = 4))
# Out:
# <table class="table" style="width: auto !important; margin-left: auto; margin-right: auto;">
# <caption>Model Summary</caption>
#  <thead>
# <tr>
# <th style="empty-cells: hide;border-bottom:hidden;" colspan="1"></th>
# <th style="border-bottom:hidden;padding-bottom:0; padding-left:3px;padding-right:3px;text-align: center; " colspan="4"><div style="border-bottom: 1px solid #ddd; padding-bottom: 5px; ">Coefficients</div></th>
# </tr>
#   <tr>
#    <th style="text-align:left;"> Term </th>
#    <th style="text-align:right;"> Estimate </th>
#    <th style="text-align:right;"> Std_Error </th>
#    <th style="text-align:right;"> t_value </th>
#    <th style="text-align:right;"> Pr </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> pheno_social_isolation </td>
#    <td style="text-align:right;"> 0.2413736 </td>
#    <td style="text-align:right;"> 0.0982182 </td>
#    <td style="text-align:right;"> 2.457525 </td>
#    <td style="text-align:right;"> 0.0157284 </td>
#   </tr>
# </tbody>
# </table>

# %%
# Fit the model
model <- lm(bold_AAL_Frontal_Med_Orb_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit, data = fmri_data_male)

# %%
plot(fmri_data_male$pheno_social_isolation, fmri_data_male$bold_AAL_Frontal_Med_Orb_R_t1t2ratio, 
     main = "Regression of bold_AAL_Frontal_Med_Orb_R_t1t2ratio on pheno_social_isolation",
     xlab = "pheno_social_isolation", 
     ylab = "bold_AAL_Frontal_Med_Orb_R_t1t2ratio")
abline(model, col = "red")
# Out:
# Warning message in abline(model, col = "red"):
# “only using the first two of 3 regression coefficients”
# Plot with title “Regression of bold_AAL_Frontal_Med_Orb_R_t1t2ratio on pheno_social_isolation”

# %%
# Plot using ggplot2
ggplot(fmri_data_male, aes(x = pheno_social_isolation, y = bold_AAL_Frontal_Med_Orb_R_t1t2ratio)) +
  geom_point() +  # Add points
  geom_smooth(method = "lm", col = "blue") +  # Add regression line
  labs(title = "Male Frontal Medial Orbital T1/T2 Ratio vs. Social Isolation",
       x = "Social Isolation", 
       y = "T1/T2 Ratio") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Plot using ggplot2
ggplot(fmri_data_female, aes(x = pheno_social_isolation, y = bold_AAL_Frontal_Med_Orb_R_t1t2ratio)) +
  geom_point() +  # Add points
  geom_smooth(method = "lm", col = "blue") +  # Add regression line
  labs(title = "Female Frontal Medial Orbital T1/T2 Ratio vs. Social Isolation",
       x = "Social Isolation", 
       y = "T1/T2 Ratio") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 3 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 3 rows containing missing values or values outside the scale range (`geom_point()`).”
# plot without title

# %%
# Subset the data frame based on the threshold
no_outliers_male <- fmri_data_male[fmri_data_male$bold_AAL_Frontal_Med_Orb_R_t1t2ratio < 10, ]

# %%
# Subset the data frame based on the threshold
no_outliers_female <- fmri_data_female[fmri_data_female$bold_AAL_Frontal_Med_Orb_R_t1t2ratio < 10, ]

# %%
# Plot using ggplot2
ggplot(no_outliers_male, aes(x = pheno_social_isolation, y = bold_AAL_Frontal_Med_Orb_R_t1t2ratio)) +
  geom_point() +  # Add points
  geom_smooth(method = "lm", col = "blue") +  # Add regression line
  labs(title = "Male Frontal Medial Orbital T1/T2 Ratio vs. Social Isolation",
       x = "Social Isolation", 
       y = "T1/T2 Ratio") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Plot using ggplot2
ggplot(no_outliers_female, aes(x = pheno_social_isolation, y = bold_AAL_Frontal_Med_Orb_R_t1t2ratio)) +
  geom_point() +  # Add points
  geom_smooth(method = "lm", col = "blue") +  # Add regression line
  labs(title = "Female Frontal Medial Orbital T1/T2 Ratio vs. Social Isolation",
       x = "Social Isolation", 
       y = "T1/T2 Ratio") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 3 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 3 rows containing missing values or values outside the scale range (`geom_point()`).”
# plot without title

# %%
fmri_data_male['bold_AAL_Frontal_Med_Orb_R_t1t2ratio']
# Out:
#     bold_AAL_Frontal_Med_Orb_R_t1t2ratio
# 1   3.016433
# 20  3.037712
# 29  2.797823
# 40  5.793920
# 42  4.346113
# 44  4.497026
# 45  4.003023
# 61  3.413632
# 68  1.426750
# 70  2.596257
# 71  3.649460
# 88  5.372639
# 89  3.200514
# 102 0.000000
# 103 1.864242
# 127 4.533032
# 133 3.146277
# 135 1.597172
# 139 1.778344
# 143 3.010553
# 150 2.597574
# 154 4.908602
# 157 4.009442
# 164 5.092331
# 171 1.297683
# 172 3.893913
# 174 1.114586
# 179 1.595600
# 180 5.461298
# 182 3.429375
# ⋮   ⋮
# 398 -4.3196908
# 403  1.5834267
# 404  1.8409583
# 417  4.5943029
# 421  2.0181833
# 429  5.2660512
# 431  1.0545191
# 432  4.2661499
# 434  1.7431045
# 435  4.0412744
# 438  3.6062998
# 440  3.5450026
# 455  3.7853764
# 456  1.5434571
# 458  3.7599338
# 467  4.5751940
# 477  1.5680013
# 481  3.2900981
# 487  3.4935806
# 489  3.5785621
# 504  2.3790714
# 530  3.0682145
# 533  2.9248824
# 536  1.0425027
# 537  1.9217717
# 542  4.9133365
# 548  3.3932638
# 555  1.5168917
# 556  5.1389571
# 561  0.3010922

# %%
fmri_data_female['bold_AAL_Frontal_Med_Orb_R_t1t2ratio']
# Out:
#     bold_AAL_Frontal_Med_Orb_R_t1t2ratio
# 2   1.380575
# 3   2.316938
# 4   4.190729
# 6   3.548432
# 7   5.283615
# 8   2.644875
# 9   5.397075
# 10  4.414710
# 13  3.217794
# 14  2.367557
# 15  4.928797
# 16  3.252361
# 21  1.327236
# 22  2.704561
# 25  2.231929
# 26  3.685023
# 28  1.292039
# 31  5.230658
# 32  3.001989
# 33  5.387089
# 34  6.298871
# 35  4.391912
# 37  5.504084
# 38  6.752787
# 39  4.810913
# 43  3.580752
# 47  3.306582
# 48  3.484284
# 49  3.157208
# 50  3.653491
# ⋮   ⋮
# 515 4.690795
# 517 3.685879
# 518 3.520952
# 519 1.529814
# 524 3.852813
# 525 2.334932
# 527 3.293026
# 528 7.138509
# 529 1.437483
# 531 2.377163
# 532 1.464169
# 534 2.023589
# 535 3.458724
# 538 3.161911
# 539 2.770844
# 540 4.993046
# 541 2.535303
# 543 1.834863
# 544 2.268979
# 545 3.024215
# 546 4.506974
# 549 5.111526
# 553 3.500155
# 557 4.084377
# 558 5.574460
# 559 1.879685
# 562 1.548819
# 563 6.224581
# 564 2.112965
# 565 4.856941

# %%
install.packages("modelsummary")
# Out:
# also installing the dependencies ‘bayestestR’, ‘datawizard’, ‘checkmate’, ‘insight’, ‘parameters’, ‘performance’, ‘tables’, ‘tinytable’

# %%
model <- lm(bold_AAL_Frontal_Med_Orb_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit, data = no_outliers_male)

# %%
library(modelsummary)
modelsummary(model)
# Out:
# `modelsummary` 2.0.0 now uses `tinytable` as its default table-drawing
#   backend. Learn more at: https://vincentarelbundock.github.io/tinytable/
#
# Revert to `kableExtra` for one session:
#
#   options(modelsummary_factory_default = 'kableExtra')
#   options(modelsummary_factory_latex = 'kableExtra')
#   options(modelsummary_factory_html = 'kableExtra')
#
# Silence this message forever:
#
#   config_modelsummary(startup_message = FALSE)
# +------------------------+----------+
# |                        | (1)      |
# +========================+==========+
# | (Intercept)            | 7.840    |
# +------------------------+----------+
# |                        | (1.521)  |
# +------------------------+----------+
# | pheno_social_isolation | -0.400   |
# +------------------------+----------+
# |                        | (0.247)  |
# +------------------------+----------+
# | pheno_age_at_visit     | -0.048   |
# +------------------------+----------+
# |                        | (0.020)  |
# +------------------------+----------+
# | Num.Obs.               | 101      |
# +------------------------+----------+
# | R2                     | 0.109    |
# +------------------------+----------+
# | R2 Adj.                | 0.091    |
# +------------------------+----------+
# | AIC                    | 362.8    |
# +------------------------+----------+
# | BIC                    | 373.3    |
# +------------------------+----------+
# | Log.Lik.               | -177.412 |
# +------------------------+----------+
# | RMSE                   | 1.40     |
# +------------------------+----------+

# %%
kableExtra::kable(x = broom::tidy(model), format = "pipe")
# Out:
# |term                   |   estimate| std.error| statistic|   p.value|
# |:----------------------|----------:|---------:|---------:|---------:|
# |(Intercept)            |  7.8397461| 1.5211207|  5.153928| 0.0000013|
# |pheno_social_isolation | -0.3999190| 0.2472145| -1.617700| 0.1089416|
# |pheno_age_at_visit     | -0.0476333| 0.0196553| -2.423432| 0.0172094|

# %%
install.packages("webshot2")
# Out:
# also installing the dependencies ‘AsioHeaders’, ‘websocket’, ‘chromote’

# %%
# Install phantomjs if it's not already installed
webshot::install_phantomjs()

# Fit a model (for example purposes)
model <- lm(mpg ~ cyl + hp, data = mtcars)

# Create the table using kableExtra
table_html <- kableExtra::kable(x = broom::tidy(model), format = "html") %>%
  kable_styling(bootstrap_options = "striped", full_width = F)

# Save the table as an HTML file
save_kable(table_html, "table.html")

# Convert the HTML to a PNG using webshot
webshot2::webshot("table.html", file = "table.png")
# Out:
# Error in loadNamespace(x): there is no package called ‘webshot’
# Traceback:
#
# 1. loadNamespace(x)
# 2. withRestarts(stop(cond), retry_loadNamespace = function() NULL)
# 3. withOneRestart(expr, restarts[[1L]])
# 4. doWithOneRestart(return(expr), restart)
